# %%
# Importar as bibliotecas necessárias: destaque para pytorch

import numpy as np
import PIL.Image

import torch, torchvision
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
import time

from matplotlib import pyplot as plt

import os

# %%
image_size = 100

# Transformando as imagens: para modelos mais robustos tem que caprichar no data augmentation!
# Nesse caso não fizemos nada além do redimensionamento da imagem, mas é sempre bom fazer rotações,
# espelhamentos, crop randomicos pra garantir 
transformacoes_de_imagens = { 
    'treino': transforms.Compose([
        transforms.Resize(size=[image_size, image_size]),
        transforms.ToTensor(),
    ]),
    'validacao': transforms.Compose([
        transforms.Resize(size=[image_size, image_size]),
        transforms.ToTensor(),
    ]),
    'teste': transforms.Compose([
        transforms.Resize(size=[image_size, image_size]),
        transforms.ToTensor(),
    ])
}

# %%
# Carregar as imagens
# Determinar as pastas de treino, validação e teste

dataset = r'./data/'

pasta_treino = os.path.join(dataset, 'treino')
pasta_validacao = os.path.join(dataset, 'validacao')
pasta_teste = os.path.join(dataset, 'teste')

# %%
# Tamanho do batch de treinamento
bs = 8

# Determinando o número de classes
numero_de_classes = len(os.listdir(pasta_validacao))

# %%
numero_de_classes
# Out:
# 3

# %%
# Carregar as imagens usando o datasets do torchvision
data = {
    'treino': datasets.ImageFolder(root=pasta_treino, transform=transformacoes_de_imagens['treino']),
    'validacao': datasets.ImageFolder(root=pasta_validacao, transform=transformacoes_de_imagens['validacao'])
}

# %%
data
# Out:
# {'treino': Dataset ImageFolder
#      Number of datapoints: 1616
#      Root location: ./data/treino
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=[100, 100], interpolation=bilinear, max_size=None, antialias=None)
#                 ToTensor()
#             ),
#  'validacao': Dataset ImageFolder
#      Number of datapoints: 27
#      Root location: ./data/validacao
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=[100, 100], interpolation=bilinear, max_size=None, antialias=None)
#                 ToTensor()
#             )}

# %%
# Mapear os índices com os nomes das classes (entregue e devolvido)
indice_para_classe = {v: k for k, v in data['treino'].class_to_idx.items()}
print(indice_para_classe)

# Quantidade de imagens para serem utilizados para calcular erro médio e acurácia
num_imagens_treino = len(data['treino'])
num_imagens_validacao = len(data['validacao'])

# Cria os DataLoaders para treino e validação
data_loader_treino = DataLoader(data['treino'], batch_size=bs, shuffle=True)
data_loader_validacao = DataLoader(data['validacao'], batch_size=bs, shuffle=True)
# Out:
# {0: 'assinado', 1: 'nao_assinado', 2: 'nao_e_assinatura'}

# %%
from IPython.display import Image 

# Mostrar algumas imagens
for classe in indice_para_classe.values():
    pasta_classe = os.path.join(pasta_treino, classe)
    arquivo_imagem = os.listdir(pasta_classe)[1]
    img = Image(filename=os.path.join(pasta_classe, arquivo_imagem))
    display(img)

# %%
alexnet = models.alexnet(pretrained=True)
alexnet
# Out:
# c:\Python310\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# c:\Python310\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Congelar os parametros da rede pré-treinada
for param in alexnet.parameters():
    param.requires_grad = False

# %%
# Mudar a última camada para alterar o número de classes
alexnet.classifier[6] = nn.Linear(4096, numero_de_classes)
alexnet.classifier.add_module("7", nn.LogSoftmax(dim = 1))
alexnet
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=3, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )

# %%
# Definição de algoritmo de otimização de gradiente descendente e função de erro
funcao_erro = nn.NLLLoss() # negative log likelihood loss
otimizador = optim.Adam(alexnet.parameters()) # otimizador de passos para o SGD
otimizador
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )

# %%
def treinar_e_validar(modelo, metrica_erro, otimizador_sgd, epocas=25):
    '''
    Função para treinamento e validação
    Parâmetros
        :param modelo: modelo para treinar e validar
        :param metrica_erro: critério de erro para minização
        :param otimizador_sgd: otimizador para calcular os gradientes
        :param epocas: número de épocas (default=25)
  
    Retorna
        melhor_modelo: modelo treinado com a melhor acurácia na validação
        historico: (dicionário): histórico com erro no treinamento, erro na validação e acurácia
    '''
    
    # inicializando historico, a melhor acuracia de validação e o melhor modelo de acordo com a validação
    historico = []
    melhor_acuracia = 0.0
    melhor_modelo = None

    # Cada época perpassa todas as imagens do treino e calcula erros de treino e validação
    # para aprendizado da rede neural
    for epoca in range(epocas):
        inicio_epoca = time.time()
        print("\n\nÉpoca: {}/{}".format(epoca+1, epocas))
        
        # Mudar o modelo para modo treino: vai atualizar os parametros da rede neural
        modelo.train()
        
        # Erro e acurácia de treino nessa época
        erro_treino = 0.0
        acuracia_treino = 0.0
        
        # Erro e acurácia de validação nessa época
        erro_validacao = 0.0
        acuracia_validacao = 0.0
        
        # Itera a cada lote de imagem. As entradas são os tensores do lote (batch)
        # e o label são as classificações de cada imagem do lote: 
        # chocolate, guaraná ou coca cola (0, 1 e 2)
        for i, (entradas, labels) in enumerate(data_loader_treino):

            # joga pra GPU ou CPU, dependendo do seu hardware
            entradas = entradas.to(device)
            labels = labels.to(device)
            
            # Limpar os gradientes: zerar os gradientes
            otimizador_sgd.zero_grad()
            
            # Forward pass - calcular saídas a partir das entradas utilizando o modelo
            saidas = modelo(entradas)
            
            # Calcular erro das saidas que foram preditas no forward pass
            # comparando com as classificacoes reais (predito vs real)
            erro = metrica_erro(saidas, labels)
            
            # Realizar backpropagation do erro para treinar os coeficientes da rede
            erro.backward()
            
            # Atualizar os parâmetros do otimizador (no nosso caso, Adam Optimizer)
            otimizador_sgd.step()
            
            # Calcular o erro total para esse lote (batch) e soma o erro no treino
            erro_treino += erro.item() * entradas.size(0)
            
            # Cálculo da acurácia
            # Pra calcular a acurácia temos que buscar as classes preditas para cada imagem no lote
            
            # Cada tensor é uma imagem do lote com três posições: probabilidades de cada classe
            # torch.max vai retornar o valor da maior probabilidade, bem como a posição no tensor (tupla de saída)
            # A posição, portanto, vai indicar a classe com maior probabilidade (0,1 ou 2)
            # 1o busca o valor máximo de cada tensor de cada imagem, que vai dar 
            valores_maximos, indices_dos_valores_maximos = torch.max(saidas.data, 1)
            predicoes_corretas = indices_dos_valores_maximos.eq(labels.data.view_as(indices_dos_valores_maximos))
            
            # Converter os acertos para float e calcular a acurácia média
            acuracia = torch.mean(predicoes_corretas.type(torch.FloatTensor))
            
            # Calcular a acurácia total de treino do lote todo e adicionar a em train_acc
            acuracia_treino += acuracia.item() * entradas.size(0)
            
            print("Treino - Lote número {:03d}, Erro: {:.4f}, Acurácia: {:.4f}".format(i, erro.item(), acuracia.item()))

            
        # Validação - não é necessário rastrear os gradientes, pois o modelo não vai ser treinado com a validação
        with torch.no_grad():

            # Mudando de treino para validação
            modelo.eval()

            # Iteração de validação
            for j, (entradas, labels) in enumerate(data_loader_validacao):
                entradas = entradas.to(device)
                labels = labels.to(device)

                # Forward pass de validação
                saidas = modelo(entradas)

                # Calcular erro de validação
                erro = metrica_erro(saidas, labels)

                # Calcular erro de validação e adicionar a valid_loss
                erro_validacao += erro.item() * entradas.size(0)

                # Calcular a acurácia de validação
                valores_maximos, indices_dos_valores_maximos = torch.max(saidas.data, 1)
                predicoes_corretas = indices_dos_valores_maximos.eq(labels.data.view_as(indices_dos_valores_maximos))

                # Converter os acertos para float e calcular a acurácia média
                acuracia = torch.mean(predicoes_corretas.type(torch.FloatTensor))

                # Calcular a acurácia total de validação do lote todo e adicionar a em train_acc
                acuracia_validacao += acuracia.item() * entradas.size(0)

                print("Validação - Lote número: {:03d}, Erro: {:.4f}, Acurácia: {:.4f}".format(j, erro.item(), acuracia.item()))
            
        # Calcular a média de erro e acurácia no treino
        erro_medio_treino = erro_treino/num_imagens_treino
        acuracia_media_treino = acuracia_treino/num_imagens_treino

        # Calcular a média de erro e acurácia na validação
        erro_medio_validacao = erro_validacao/num_imagens_validacao
        acuracia_media_validacao = acuracia_validacao/num_imagens_validacao

        # Incluir no histórico os erros e acurácias méidas
        historico.append([erro_medio_treino, erro_medio_validacao, acuracia_media_treino, acuracia_media_validacao])
                
        fim_epoca = time.time()
    
        print("Época : {:03d}, Treino: Erro: {:.4f}, Acurácia: {:.4f}%, \n\t\tValidação : Erro : {:.4f}, Acurácia: {:.4f}%, Tempo: {:.4f}s".format(epoca+1, erro_medio_treino, acuracia_media_treino*100, erro_medio_validacao, acuracia_media_validacao*100, fim_epoca-inicio_epoca))
        
        # Testa se a acurácia na validação desse modelo nessa época é a melhor
        # Se for a melhor, salva no melhor modelo e na melhor acurácia
        if acuracia_media_validacao > melhor_acuracia:
            melhor_acuracia = acuracia_media_validacao
            torch.save(modelo, './modelos/melhor_modelo.pt')
            melhor_modelo = modelo
            
    return melhor_modelo, historico

# %%
# Se você for rico e tiver uma RTX 3080 (que sonho!!)
# Mas se não for, sem problemas, sua CPU provavelmente vai dar conta do recado!
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Imprime se vai ser CPU ou alguma GPU
print(f'{device}\n')

# Define o número de épocas
numero_de_epocas = 20

# treina o modelo! Finalmente!!
modelo_treinado, historico = treinar_e_validar(alexnet, funcao_erro, otimizador, numero_de_epocas)
# Out:
# cpu
#
#
#
# Época: 1/20
# Treino - Lote número 000, Erro: 1.1304, Acurácia: 0.3750
# Treino - Lote número 001, Erro: 0.9958, Acurácia: 0.5000
# Treino - Lote número 002, Erro: 1.3057, Acurácia: 0.6250
# Treino - Lote número 003, Erro: 0.1918, Acurácia: 1.0000
# Treino - Lote número 004, Erro: 0.2700, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.6276, Acurácia: 0.8750
# Treino - Lote número 006, Erro: 0.0336, Acurácia: 1.0000
# Treino - Lote número 007, Erro: 0.9710, Acurácia: 0.7500
# Treino - Lote número 008, Erro: 0.1160, Acurácia: 1.0000
# Treino - Lote número 009, Erro: 0.7838, Acurácia: 0.8750
# Treino - Lote número 010, Erro: 0.2176, Acurácia: 0.8750
# Treino - Lote número 011, Erro: 0.3985, Acurácia: 0.7500
# Treino - Lote número 012, Erro: 0.4738, Acurácia: 0.8750
# Treino - Lote número 013, Erro: 0.1744, Acurácia: 1.0000
# Treino - Lote número 014, Erro: 0.0878, Acurácia: 1.0000
# Treino - Lote número 015, Erro: 0.0433, Acurácia: 1.0000
# Treino - Lote número 016, Erro: 0.8829, Acurácia: 0.8750
# Treino - Lote número 017, Erro: 0.2950, Acurácia: 0.7500
# Treino - Lote número 018, Erro: 0.4630, Acurácia: 0.8750
# Treino - Lote número 019, Erro: 0.0670, Acurácia: 1.0000
# Treino - Lote número 020, Erro: 0.4928, Acurácia: 0.8750
# Treino - Lote número 021, Erro: 0.4634, Acurácia: 0.8750
# Treino - Lote número 022, Erro: 0.5465, Acurácia: 0.8750
# Treino - Lote número 023, Erro: 0.5682, Acurácia: 0.8750
# Treino - Lote número 024, Erro: 0.0268, Acurácia: 1.0000
# Treino - Lote número 025, Erro: 0.7619, Acurácia: 0.7500
# Treino - Lote número 026, Erro: 0.4117, Acurácia: 0.7500
# Treino - Lote número 027, Erro: 1.1812, Acurácia: 0.6250
# Treino - Lote número 028, Erro: 0.5059, Acurácia: 0.7500
# Treino - Lote número 029, Erro: 0.9636, Acurácia: 0.6250
# Treino - Lote número 030, Erro: 0.2871, Acurácia: 0.8750
# Treino - Lote número 031, Erro: 0.5279, Acurácia: 0.6250
# Treino - Lote número 032, Erro: 0.2898, Acurácia: 0.8750
# Treino - Lote número 033, Erro: 0.3030, Acurácia: 0.8750
# Treino - Lote número 034, Erro: 0.3401, Acurácia: 0.7500
# Treino - Lote número 035, Erro: 0.3597, Acurácia: 0.8750
# Treino - Lote número 036, Erro: 0.3217, Acurácia: 0.8750
# Treino - Lote número 037, Erro: 2.1357, Acurácia: 0.5000
# Treino - Lote número 038, Erro: 0.0633, Acurácia: 1.0000
# Treino - Lote número 039, Erro: 0.3064, Acurácia: 0.8750
# Treino - Lote número 040, Erro: 0.4918, Acurácia: 0.7500
# Treino - Lote número 041, Erro: 0.0627, Acurácia: 1.0000
# Treino - Lote número 042, Erro: 0.8715, Acurácia: 0.8750
# Treino - Lote número 043, Erro: 0.1576, Acurácia: 0.8750
# Treino - Lote número 044, Erro: 0.7362, Acurácia: 0.3750
# Treino - Lote número 045, Erro: 0.4910, Acurácia: 0.7500
# Treino - Lote número 046, Erro: 0.3386, Acurácia: 0.7500
# Treino - Lote número 047, Erro: 0.6649, Acurácia: 0.6250
# Treino - Lote número 048, Erro: 0.5417, Acurácia: 0.6250
# Treino - Lote número 049, Erro: 0.2740, Acurácia: 1.0000
# Treino - Lote número 050, Erro: 1.6877, Acurácia: 0.5000
# Treino - Lote número 051, Erro: 0.7164, Acurácia: 0.7500
# Treino - Lote número 052, Erro: 0.9905, Acurácia: 0.7500
# Treino - Lote número 053, Erro: 0.1251, Acurácia: 1.0000
# Treino - Lote número 054, Erro: 0.1091, Acurácia: 1.0000
# Treino - Lote número 055, Erro: 0.5479, Acurácia: 0.8750
# Treino - Lote número 056, Erro: 0.0818, Acurácia: 1.0000
# Treino - Lote número 057, Erro: 0.0956, Acurácia: 1.0000
# Treino - Lote número 058, Erro: 0.9078, Acurácia: 0.7500
# Treino - Lote número 059, Erro: 0.7569, Acurácia: 0.7500
# Treino - Lote número 060, Erro: 0.8018, Acurácia: 0.7500
# Treino - Lote número 061, Erro: 0.2439, Acurácia: 0.8750
# Treino - Lote número 062, Erro: 0.1627, Acurácia: 1.0000
# Treino - Lote número 063, Erro: 0.4123, Acurácia: 0.7500
# Treino - Lote número 064, Erro: 0.3763, Acurácia: 0.8750
# Treino - Lote número 065, Erro: 0.5524, Acurácia: 0.7500
# Treino - Lote número 066, Erro: 0.5809, Acurácia: 0.8750
# Treino - Lote número 067, Erro: 0.3507, Acurácia: 0.8750
# Treino - Lote número 068, Erro: 0.6436, Acurácia: 0.6250
# Treino - Lote número 069, Erro: 0.3337, Acurácia: 0.8750
# Treino - Lote número 070, Erro: 0.3479, Acurácia: 0.7500
# Treino - Lote número 071, Erro: 0.1600, Acurácia: 1.0000
# Treino - Lote número 072, Erro: 0.0830, Acurácia: 1.0000
# Treino - Lote número 073, Erro: 0.0838, Acurácia: 1.0000
# Treino - Lote número 074, Erro: 0.4090, Acurácia: 0.8750
# Treino - Lote número 075, Erro: 0.1867, Acurácia: 0.8750
# Treino - Lote número 076, Erro: 0.3266, Acurácia: 0.8750
# Treino - Lote número 077, Erro: 0.1078, Acurácia: 1.0000
# Treino - Lote número 078, Erro: 0.6367, Acurácia: 0.7500
# Treino - Lote número 079, Erro: 0.9717, Acurácia: 0.7500
# Treino - Lote número 080, Erro: 0.1385, Acurácia: 0.8750
# Treino - Lote número 081, Erro: 1.1207, Acurácia: 0.8750
# Treino - Lote número 082, Erro: 0.3176, Acurácia: 0.8750
# Treino - Lote número 083, Erro: 0.6993, Acurácia: 0.6250
# Treino - Lote número 084, Erro: 0.1599, Acurácia: 0.8750
# Treino - Lote número 085, Erro: 0.7248, Acurácia: 0.7500
# Treino - Lote número 086, Erro: 0.1230, Acurácia: 1.0000
# Treino - Lote número 087, Erro: 0.2007, Acurácia: 1.0000
# Treino - Lote número 088, Erro: 0.7267, Acurácia: 0.7500
# Treino - Lote número 089, Erro: 0.0589, Acurácia: 1.0000
# Treino - Lote número 090, Erro: 0.2286, Acurácia: 0.8750
# Treino - Lote número 091, Erro: 0.6774, Acurácia: 0.8750
# Treino - Lote número 092, Erro: 0.4224, Acurácia: 0.8750
# Treino - Lote número 093, Erro: 0.7600, Acurácia: 0.7500
# Treino - Lote número 094, Erro: 0.3098, Acurácia: 0.8750
# Treino - Lote número 095, Erro: 0.4922, Acurácia: 0.8750
# Treino - Lote número 096, Erro: 0.5331, Acurácia: 0.8750
# Treino - Lote número 097, Erro: 0.4487, Acurácia: 0.7500
# Treino - Lote número 098, Erro: 0.6710, Acurácia: 0.6250
# Treino - Lote número 099, Erro: 0.3969, Acurácia: 0.8750
# Treino - Lote número 100, Erro: 0.4850, Acurácia: 0.8750
# Treino - Lote número 101, Erro: 0.4411, Acurácia: 0.7500
# Treino - Lote número 102, Erro: 0.3488, Acurácia: 0.8750
# Treino - Lote número 103, Erro: 0.1251, Acurácia: 1.0000
# Treino - Lote número 104, Erro: 1.1122, Acurácia: 0.7500
# Treino - Lote número 105, Erro: 0.5557, Acurácia: 0.7500
# Treino - Lote número 106, Erro: 0.5531, Acurácia: 0.7500
# Treino - Lote número 107, Erro: 0.9318, Acurácia: 0.6250
# Treino - Lote número 108, Erro: 0.3257, Acurácia: 0.8750
# Treino - Lote número 109, Erro: 0.3493, Acurácia: 0.7500
# Treino - Lote número 110, Erro: 1.6816, Acurácia: 0.5000
# Treino - Lote número 111, Erro: 0.3952, Acurácia: 0.7500
# Treino - Lote número 112, Erro: 0.6221, Acurácia: 0.7500
# Treino - Lote número 113, Erro: 0.4104, Acurácia: 0.8750
# Treino - Lote número 114, Erro: 0.7386, Acurácia: 0.8750
# Treino - Lote número 115, Erro: 0.2358, Acurácia: 0.8750
# Treino - Lote número 116, Erro: 0.9552, Acurácia: 0.8750
# Treino - Lote número 117, Erro: 1.0046, Acurácia: 0.5000
# Treino - Lote número 118, Erro: 0.6137, Acurácia: 0.7500
# Treino - Lote número 119, Erro: 0.6638, Acurácia: 0.6250
# Treino - Lote número 120, Erro: 0.5080, Acurácia: 0.6250
# Treino - Lote número 121, Erro: 0.4522, Acurácia: 0.7500
# Treino - Lote número 122, Erro: 0.7604, Acurácia: 0.5000
# Treino - Lote número 123, Erro: 0.5637, Acurácia: 0.7500
# Treino - Lote número 124, Erro: 1.1784, Acurácia: 0.7500
# Treino - Lote número 125, Erro: 0.9321, Acurácia: 0.8750
# Treino - Lote número 126, Erro: 0.1850, Acurácia: 1.0000
# Treino - Lote número 127, Erro: 0.5502, Acurácia: 0.7500
# Treino - Lote número 128, Erro: 0.2914, Acurácia: 1.0000
# Treino - Lote número 129, Erro: 0.4484, Acurácia: 0.7500
# Treino - Lote número 130, Erro: 0.3614, Acurácia: 0.7500
# Treino - Lote número 131, Erro: 0.2506, Acurácia: 0.8750
# Treino - Lote número 132, Erro: 0.1610, Acurácia: 1.0000
# Treino - Lote número 133, Erro: 0.3330, Acurácia: 0.8750
# Treino - Lote número 134, Erro: 0.1705, Acurácia: 0.8750
# Treino - Lote número 135, Erro: 0.1887, Acurácia: 0.8750
# Treino - Lote número 136, Erro: 0.4340, Acurácia: 0.8750
# Treino - Lote número 137, Erro: 0.0548, Acurácia: 1.0000
# Treino - Lote número 138, Erro: 0.1160, Acurácia: 1.0000
# Treino - Lote número 139, Erro: 0.3560, Acurácia: 0.7500
# Treino - Lote número 140, Erro: 0.1730, Acurácia: 1.0000
# Treino - Lote número 141, Erro: 0.9072, Acurácia: 0.6250
# Treino - Lote número 142, Erro: 0.3687, Acurácia: 0.8750
# Treino - Lote número 143, Erro: 0.1111, Acurácia: 1.0000
# Treino - Lote número 144, Erro: 0.0899, Acurácia: 1.0000
# Treino - Lote número 145, Erro: 0.4065, Acurácia: 0.7500
# Treino - Lote número 146, Erro: 0.2099, Acurácia: 1.0000
# Treino - Lote número 147, Erro: 0.4608, Acurácia: 0.8750
# Treino - Lote número 148, Erro: 0.2563, Acurácia: 0.8750
# Treino - Lote número 149, Erro: 0.0932, Acurácia: 1.0000
# Treino - Lote número 150, Erro: 0.1993, Acurácia: 0.8750
# Treino - Lote número 151, Erro: 0.4543, Acurácia: 0.8750
# Treino - Lote número 152, Erro: 0.1805, Acurácia: 1.0000
# Treino - Lote número 153, Erro: 0.4440, Acurácia: 0.6250
# Treino - Lote número 154, Erro: 0.1512, Acurácia: 1.0000
# Treino - Lote número 155, Erro: 0.4189, Acurácia: 0.8750
# Treino - Lote número 156, Erro: 0.7169, Acurácia: 0.7500
# Treino - Lote número 157, Erro: 0.1072, Acurácia: 1.0000
# Treino - Lote número 158, Erro: 0.2446, Acurácia: 0.8750
# Treino - Lote número 159, Erro: 0.3041, Acurácia: 0.8750
# Treino - Lote número 160, Erro: 0.5297, Acurácia: 0.6250
# Treino - Lote número 161, Erro: 1.6462, Acurácia: 0.8750
# Treino - Lote número 162, Erro: 0.2617, Acurácia: 1.0000
# Treino - Lote número 163, Erro: 0.3840, Acurácia: 0.7500
# Treino - Lote número 164, Erro: 0.0574, Acurácia: 1.0000
# Treino - Lote número 165, Erro: 0.1178, Acurácia: 1.0000
# Treino - Lote número 166, Erro: 0.2946, Acurácia: 0.8750
# Treino - Lote número 167, Erro: 0.4244, Acurácia: 0.6250
# Treino - Lote número 168, Erro: 0.0854, Acurácia: 1.0000
# Treino - Lote número 169, Erro: 0.1304, Acurácia: 1.0000
# Treino - Lote número 170, Erro: 0.0993, Acurácia: 1.0000
# Treino - Lote número 171, Erro: 0.4656, Acurácia: 0.8750
# Treino - Lote número 172, Erro: 0.4337, Acurácia: 0.8750
# Treino - Lote número 173, Erro: 0.0396, Acurácia: 1.0000
# Treino - Lote número 174, Erro: 0.1057, Acurácia: 1.0000
# Treino - Lote número 175, Erro: 0.0702, Acurácia: 1.0000
# Treino - Lote número 176, Erro: 0.8616, Acurácia: 0.7500
# Treino - Lote número 177, Erro: 0.0601, Acurácia: 1.0000
# Treino - Lote número 178, Erro: 0.6009, Acurácia: 0.7500
# Treino - Lote número 179, Erro: 0.0726, Acurácia: 1.0000
# Treino - Lote número 180, Erro: 0.1900, Acurácia: 1.0000
# Treino - Lote número 181, Erro: 0.1537, Acurácia: 0.8750
# Treino - Lote número 182, Erro: 0.0776, Acurácia: 1.0000
# Treino - Lote número 183, Erro: 0.1654, Acurácia: 1.0000
# Treino - Lote número 184, Erro: 0.1952, Acurácia: 1.0000
# Treino - Lote número 185, Erro: 0.2619, Acurácia: 1.0000
# Treino - Lote número 186, Erro: 0.0495, Acurácia: 1.0000
# Treino - Lote número 187, Erro: 0.0930, Acurácia: 0.8750
# Treino - Lote número 188, Erro: 0.8443, Acurácia: 0.6250
# Treino - Lote número 189, Erro: 0.3986, Acurácia: 0.8750
# Treino - Lote número 190, Erro: 0.2409, Acurácia: 0.8750
# Treino - Lote número 191, Erro: 0.5876, Acurácia: 0.8750
# Treino - Lote número 192, Erro: 0.8065, Acurácia: 0.8750
# Treino - Lote número 193, Erro: 0.2500, Acurácia: 0.8750
# Treino - Lote número 194, Erro: 0.0385, Acurácia: 1.0000
# Treino - Lote número 195, Erro: 0.0238, Acurácia: 1.0000
# Treino - Lote número 196, Erro: 0.0903, Acurácia: 1.0000
# Treino - Lote número 197, Erro: 2.1057, Acurácia: 0.7500
# Treino - Lote número 198, Erro: 0.7303, Acurácia: 0.8750
# Treino - Lote número 199, Erro: 0.3052, Acurácia: 0.8750
# Treino - Lote número 200, Erro: 0.0666, Acurácia: 1.0000
# Treino - Lote número 201, Erro: 0.5700, Acurácia: 0.8750
# Validação - Lote número: 000, Erro: 0.7536, Acurácia: 0.7500
# Validação - Lote número: 001, Erro: 1.1340, Acurácia: 0.5000
# Validação - Lote número: 002, Erro: 1.1684, Acurácia: 0.7500
# Validação - Lote número: 003, Erro: 0.0114, Acurácia: 1.0000
# Época : 001, Treino: Erro: 0.4463, Acurácia: 84.5916%,
# 		Validação : Erro : 0.9067, Acurácia: 70.3704%, Tempo: 14.2304s
#
#
# Época: 2/20
# Treino - Lote número 000, Erro: 0.6367, Acurácia: 0.7500
# Treino - Lote número 001, Erro: 0.0752, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.2968, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.3176, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.1126, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.2539, Acurácia: 0.8750
# Treino - Lote número 006, Erro: 0.1311, Acurácia: 1.0000
# Treino - Lote número 007, Erro: 0.2435, Acurácia: 0.8750
# Treino - Lote número 008, Erro: 0.0748, Acurácia: 1.0000
# Treino - Lote número 009, Erro: 0.0298, Acurácia: 1.0000
# Treino - Lote número 010, Erro: 0.3941, Acurácia: 0.8750
# Treino - Lote número 011, Erro: 0.2709, Acurácia: 0.8750
# Treino - Lote número 012, Erro: 0.3996, Acurácia: 0.8750
# Treino - Lote número 013, Erro: 0.3967, Acurácia: 0.8750
# Treino - Lote número 014, Erro: 0.2939, Acurácia: 0.8750
# Treino - Lote número 015, Erro: 0.0727, Acurácia: 1.0000
# Treino - Lote número 016, Erro: 0.2695, Acurácia: 0.8750
# Treino - Lote número 017, Erro: 0.0571, Acurácia: 1.0000
# Treino - Lote número 018, Erro: 0.8241, Acurácia: 0.6250
# Treino - Lote número 019, Erro: 0.1769, Acurácia: 1.0000
# Treino - Lote número 020, Erro: 0.2130, Acurácia: 0.8750
# Treino - Lote número 021, Erro: 0.1990, Acurácia: 0.8750
# Treino - Lote número 022, Erro: 0.8995, Acurácia: 0.7500
# Treino - Lote número 023, Erro: 0.4714, Acurácia: 0.7500
# Treino - Lote número 024, Erro: 0.1020, Acurácia: 1.0000
# Treino - Lote número 025, Erro: 0.9534, Acurácia: 0.7500
# Treino - Lote número 026, Erro: 0.1828, Acurácia: 1.0000
# Treino - Lote número 027, Erro: 0.2604, Acurácia: 0.8750
# Treino - Lote número 028, Erro: 0.2416, Acurácia: 0.8750
# Treino - Lote número 029, Erro: 0.3722, Acurácia: 0.8750
# Treino - Lote número 030, Erro: 0.5518, Acurácia: 0.6250
# Treino - Lote número 031, Erro: 0.2183, Acurácia: 0.8750
# Treino - Lote número 032, Erro: 0.6006, Acurácia: 0.7500
# Treino - Lote número 033, Erro: 0.4307, Acurácia: 0.8750
# Treino - Lote número 034, Erro: 0.1477, Acurácia: 0.8750
# Treino - Lote número 035, Erro: 0.0541, Acurácia: 1.0000
# Treino - Lote número 036, Erro: 0.3518, Acurácia: 0.8750
# Treino - Lote número 037, Erro: 0.1936, Acurácia: 0.8750
# Treino - Lote número 038, Erro: 0.0787, Acurácia: 1.0000
# Treino - Lote número 039, Erro: 0.1427, Acurácia: 0.8750
# Treino - Lote número 040, Erro: 0.0147, Acurácia: 1.0000
# Treino - Lote número 041, Erro: 0.3604, Acurácia: 0.7500
# Treino - Lote número 042, Erro: 0.8911, Acurácia: 0.7500
# Treino - Lote número 043, Erro: 0.6851, Acurácia: 0.8750
# Treino - Lote número 044, Erro: 0.4907, Acurácia: 0.6250
# Treino - Lote número 045, Erro: 0.1218, Acurácia: 0.8750
# Treino - Lote número 046, Erro: 0.2054, Acurácia: 0.8750
# Treino - Lote número 047, Erro: 0.0608, Acurácia: 1.0000
# Treino - Lote número 048, Erro: 0.2114, Acurácia: 0.8750
# Treino - Lote número 049, Erro: 0.7776, Acurácia: 0.7500
# Treino - Lote número 050, Erro: 0.3353, Acurácia: 0.8750
# Treino - Lote número 051, Erro: 0.1551, Acurácia: 0.8750
# Treino - Lote número 052, Erro: 0.1008, Acurácia: 1.0000
# Treino - Lote número 053, Erro: 0.2401, Acurácia: 0.8750
# Treino - Lote número 054, Erro: 0.1331, Acurácia: 0.8750
# Treino - Lote número 055, Erro: 0.0302, Acurácia: 1.0000
# Treino - Lote número 056, Erro: 0.4760, Acurácia: 0.8750
# Treino - Lote número 057, Erro: 1.1603, Acurácia: 0.6250
# Treino - Lote número 058, Erro: 0.7247, Acurácia: 0.7500
# Treino - Lote número 059, Erro: 0.4984, Acurácia: 0.8750
# Treino - Lote número 060, Erro: 0.0738, Acurácia: 1.0000
# Treino - Lote número 061, Erro: 0.1606, Acurácia: 1.0000
# Treino - Lote número 062, Erro: 0.2879, Acurácia: 0.8750
# Treino - Lote número 063, Erro: 0.8314, Acurácia: 0.6250
# Treino - Lote número 064, Erro: 0.3709, Acurácia: 0.8750
# Treino - Lote número 065, Erro: 0.1796, Acurácia: 0.8750
# Treino - Lote número 066, Erro: 0.0846, Acurácia: 1.0000
# Treino - Lote número 067, Erro: 0.0229, Acurácia: 1.0000
# Treino - Lote número 068, Erro: 0.7206, Acurácia: 0.8750
# Treino - Lote número 069, Erro: 0.0119, Acurácia: 1.0000
# Treino - Lote número 070, Erro: 0.0446, Acurácia: 1.0000
# Treino - Lote número 071, Erro: 0.0171, Acurácia: 1.0000
# Treino - Lote número 072, Erro: 0.4259, Acurácia: 0.8750
# Treino - Lote número 073, Erro: 0.0202, Acurácia: 1.0000
# Treino - Lote número 074, Erro: 0.0745, Acurácia: 1.0000
# Treino - Lote número 075, Erro: 0.0754, Acurácia: 1.0000
# Treino - Lote número 076, Erro: 0.2992, Acurácia: 0.8750
# Treino - Lote número 077, Erro: 0.6632, Acurácia: 0.7500
# Treino - Lote número 078, Erro: 0.0191, Acurácia: 1.0000
# Treino - Lote número 079, Erro: 0.0445, Acurácia: 1.0000
# Treino - Lote número 080, Erro: 0.0239, Acurácia: 1.0000
# Treino - Lote número 081, Erro: 0.0077, Acurácia: 1.0000
# Treino - Lote número 082, Erro: 0.0281, Acurácia: 1.0000
# Treino - Lote número 083, Erro: 1.4116, Acurácia: 0.7500
# Treino - Lote número 084, Erro: 0.0217, Acurácia: 1.0000
# Treino - Lote número 085, Erro: 0.0438, Acurácia: 1.0000
# Treino - Lote número 086, Erro: 0.7987, Acurácia: 0.7500
# Treino - Lote número 087, Erro: 0.4892, Acurácia: 0.8750
# Treino - Lote número 088, Erro: 0.4487, Acurácia: 0.8750
# Treino - Lote número 089, Erro: 0.0635, Acurácia: 1.0000
# Treino - Lote número 090, Erro: 0.4579, Acurácia: 0.8750
# Treino - Lote número 091, Erro: 0.1575, Acurácia: 1.0000
# Treino - Lote número 092, Erro: 0.6282, Acurácia: 0.7500
# Treino - Lote número 093, Erro: 0.0822, Acurácia: 1.0000
# Treino - Lote número 094, Erro: 0.4394, Acurácia: 0.7500
# Treino - Lote número 095, Erro: 0.4613, Acurácia: 0.8750
# Treino - Lote número 096, Erro: 0.1540, Acurácia: 1.0000
# Treino - Lote número 097, Erro: 0.3607, Acurácia: 0.8750
# Treino - Lote número 098, Erro: 1.0482, Acurácia: 0.7500
# Treino - Lote número 099, Erro: 0.6074, Acurácia: 0.8750
# Treino - Lote número 100, Erro: 0.1850, Acurácia: 1.0000
# Treino - Lote número 101, Erro: 0.3221, Acurácia: 0.7500
# Treino - Lote número 102, Erro: 0.1804, Acurácia: 1.0000
# Treino - Lote número 103, Erro: 0.1293, Acurácia: 0.8750
# Treino - Lote número 104, Erro: 0.9453, Acurácia: 0.8750
# Treino - Lote número 105, Erro: 0.5643, Acurácia: 0.8750
# Treino - Lote número 106, Erro: 0.3211, Acurácia: 0.8750
# Treino - Lote número 107, Erro: 0.3699, Acurácia: 0.7500
# Treino - Lote número 108, Erro: 0.4220, Acurácia: 0.8750
# Treino - Lote número 109, Erro: 0.4482, Acurácia: 0.7500
# Treino - Lote número 110, Erro: 0.8742, Acurácia: 0.6250
# Treino - Lote número 111, Erro: 0.0440, Acurácia: 1.0000
# Treino - Lote número 112, Erro: 0.6456, Acurácia: 0.8750
# Treino - Lote número 113, Erro: 0.0228, Acurácia: 1.0000
# Treino - Lote número 114, Erro: 0.7825, Acurácia: 0.8750
# Treino - Lote número 115, Erro: 0.0849, Acurácia: 1.0000
# Treino - Lote número 116, Erro: 0.5736, Acurácia: 0.8750
# Treino - Lote número 117, Erro: 0.2179, Acurácia: 0.8750
# Treino - Lote número 118, Erro: 0.0628, Acurácia: 1.0000
# Treino - Lote número 119, Erro: 0.2188, Acurácia: 1.0000
# Treino - Lote número 120, Erro: 0.0932, Acurácia: 1.0000
# Treino - Lote número 121, Erro: 0.0242, Acurácia: 1.0000
# Treino - Lote número 122, Erro: 0.1767, Acurácia: 1.0000
# Treino - Lote número 123, Erro: 0.0747, Acurácia: 1.0000
# Treino - Lote número 124, Erro: 0.2807, Acurácia: 0.7500
# Treino - Lote número 125, Erro: 0.1882, Acurácia: 1.0000
# Treino - Lote número 126, Erro: 0.2460, Acurácia: 0.8750
# Treino - Lote número 127, Erro: 0.4912, Acurácia: 0.7500
# Treino - Lote número 128, Erro: 0.2289, Acurácia: 0.8750
# Treino - Lote número 129, Erro: 0.8162, Acurácia: 0.7500
# Treino - Lote número 130, Erro: 0.1769, Acurácia: 0.8750
# Treino - Lote número 131, Erro: 0.6424, Acurácia: 0.7500
# Treino - Lote número 132, Erro: 0.2148, Acurácia: 0.8750
# Treino - Lote número 133, Erro: 0.5846, Acurácia: 0.8750
# Treino - Lote número 134, Erro: 0.0768, Acurácia: 1.0000
# Treino - Lote número 135, Erro: 0.5458, Acurácia: 0.8750
# Treino - Lote número 136, Erro: 0.2896, Acurácia: 0.8750
# Treino - Lote número 137, Erro: 0.0586, Acurácia: 1.0000
# Treino - Lote número 138, Erro: 0.3658, Acurácia: 0.7500
# Treino - Lote número 139, Erro: 0.5148, Acurácia: 0.8750
# Treino - Lote número 140, Erro: 0.7947, Acurácia: 0.8750
# Treino - Lote número 141, Erro: 0.0875, Acurácia: 1.0000
# Treino - Lote número 142, Erro: 0.2548, Acurácia: 0.8750
# Treino - Lote número 143, Erro: 0.2771, Acurácia: 0.8750
# Treino - Lote número 144, Erro: 0.3903, Acurácia: 0.8750
# Treino - Lote número 145, Erro: 0.8400, Acurácia: 0.8750
# Treino - Lote número 146, Erro: 1.0162, Acurácia: 0.6250
# Treino - Lote número 147, Erro: 0.1198, Acurácia: 1.0000
# Treino - Lote número 148, Erro: 0.7262, Acurácia: 0.7500
# Treino - Lote número 149, Erro: 0.1786, Acurácia: 0.8750
# Treino - Lote número 150, Erro: 0.0595, Acurácia: 1.0000
# Treino - Lote número 151, Erro: 0.1504, Acurácia: 1.0000
# Treino - Lote número 152, Erro: 0.3415, Acurácia: 0.8750
# Treino - Lote número 153, Erro: 0.8461, Acurácia: 0.6250
# Treino - Lote número 154, Erro: 2.1289, Acurácia: 0.6250
# Treino - Lote número 155, Erro: 0.8111, Acurácia: 0.7500
# Treino - Lote número 156, Erro: 0.3168, Acurácia: 0.8750
# Treino - Lote número 157, Erro: 0.2092, Acurácia: 0.8750
# Treino - Lote número 158, Erro: 0.5990, Acurácia: 0.8750
# Treino - Lote número 159, Erro: 0.3742, Acurácia: 0.8750
# Treino - Lote número 160, Erro: 0.8197, Acurácia: 0.6250
# Treino - Lote número 161, Erro: 0.0944, Acurácia: 1.0000
# Treino - Lote número 162, Erro: 0.8138, Acurácia: 0.7500
# Treino - Lote número 163, Erro: 0.4260, Acurácia: 0.6250
# Treino - Lote número 164, Erro: 0.0263, Acurácia: 1.0000
# Treino - Lote número 165, Erro: 0.1830, Acurácia: 0.8750
# Treino - Lote número 166, Erro: 0.2802, Acurácia: 0.8750
# Treino - Lote número 167, Erro: 0.0809, Acurácia: 1.0000
# Treino - Lote número 168, Erro: 0.6979, Acurácia: 0.8750
# Treino - Lote número 169, Erro: 0.0390, Acurácia: 1.0000
# Treino - Lote número 170, Erro: 0.8029, Acurácia: 0.7500
# Treino - Lote número 171, Erro: 0.0549, Acurácia: 1.0000
# Treino - Lote número 172, Erro: 1.1027, Acurácia: 0.7500
# Treino - Lote número 173, Erro: 1.1597, Acurácia: 0.8750
# Treino - Lote número 174, Erro: 0.3012, Acurácia: 0.8750
# Treino - Lote número 175, Erro: 0.3923, Acurácia: 0.8750
# Treino - Lote número 176, Erro: 0.8381, Acurácia: 0.7500
# Treino - Lote número 177, Erro: 0.5025, Acurácia: 0.7500
# Treino - Lote número 178, Erro: 0.2504, Acurácia: 1.0000
# Treino - Lote número 179, Erro: 0.1083, Acurácia: 1.0000
# Treino - Lote número 180, Erro: 0.0608, Acurácia: 1.0000
# Treino - Lote número 181, Erro: 0.1838, Acurácia: 1.0000
# Treino - Lote número 182, Erro: 0.0578, Acurácia: 1.0000
# Treino - Lote número 183, Erro: 0.0188, Acurácia: 1.0000
# Treino - Lote número 184, Erro: 0.5701, Acurácia: 0.8750
# Treino - Lote número 185, Erro: 0.0144, Acurácia: 1.0000
# Treino - Lote número 186, Erro: 1.0215, Acurácia: 0.8750
# Treino - Lote número 187, Erro: 0.0801, Acurácia: 1.0000
# Treino - Lote número 188, Erro: 0.0135, Acurácia: 1.0000
# Treino - Lote número 189, Erro: 0.4642, Acurácia: 0.8750
# Treino - Lote número 190, Erro: 0.0063, Acurácia: 1.0000
# Treino - Lote número 191, Erro: 1.2864, Acurácia: 0.6250
# Treino - Lote número 192, Erro: 0.1636, Acurácia: 0.8750
# Treino - Lote número 193, Erro: 0.0364, Acurácia: 1.0000
# Treino - Lote número 194, Erro: 0.1930, Acurácia: 0.8750
# Treino - Lote número 195, Erro: 0.1537, Acurácia: 0.8750
# Treino - Lote número 196, Erro: 0.4860, Acurácia: 0.7500
# Treino - Lote número 197, Erro: 0.5411, Acurácia: 0.7500
# Treino - Lote número 198, Erro: 0.4289, Acurácia: 0.8750
# Treino - Lote número 199, Erro: 0.7461, Acurácia: 0.8750
# Treino - Lote número 200, Erro: 0.1703, Acurácia: 1.0000
# Treino - Lote número 201, Erro: 0.3501, Acurácia: 0.7500
# Validação - Lote número: 000, Erro: 1.5588, Acurácia: 0.6250
# Validação - Lote número: 001, Erro: 0.9461, Acurácia: 0.7500
# Validação - Lote número: 002, Erro: 0.4177, Acurácia: 0.7500
# Validação - Lote número: 003, Erro: 2.0715, Acurácia: 0.6667
# Época : 002, Treino: Erro: 0.3558, Acurácia: 88.4282%,
# 		Validação : Erro : 1.0961, Acurácia: 70.3704%, Tempo: 13.7458s
#
#
# Época: 3/20
# Treino - Lote número 000, Erro: 0.0409, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.4393, Acurácia: 0.8750
# Treino - Lote número 002, Erro: 0.3294, Acurácia: 0.8750
# Treino - Lote número 003, Erro: 0.4684, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.4950, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.6994, Acurácia: 0.7500
# Treino - Lote número 006, Erro: 0.0566, Acurácia: 1.0000
# Treino - Lote número 007, Erro: 0.4563, Acurácia: 0.7500
# Treino - Lote número 008, Erro: 0.0498, Acurácia: 1.0000
# Treino - Lote número 009, Erro: 0.3495, Acurácia: 0.8750
# Treino - Lote número 010, Erro: 0.2947, Acurácia: 0.8750
# Treino - Lote número 011, Erro: 0.1223, Acurácia: 1.0000
# Treino - Lote número 012, Erro: 0.0602, Acurácia: 1.0000
# Treino - Lote número 013, Erro: 0.1485, Acurácia: 1.0000
# Treino - Lote número 014, Erro: 0.3552, Acurácia: 0.8750
# Treino - Lote número 015, Erro: 0.0455, Acurácia: 1.0000
# Treino - Lote número 016, Erro: 0.3291, Acurácia: 0.7500
# Treino - Lote número 017, Erro: 0.1425, Acurácia: 0.8750
# Treino - Lote número 018, Erro: 0.3304, Acurácia: 0.8750
# Treino - Lote número 019, Erro: 0.1425, Acurácia: 0.8750
# Treino - Lote número 020, Erro: 0.3160, Acurácia: 0.8750
# Treino - Lote número 021, Erro: 0.2670, Acurácia: 0.8750
# Treino - Lote número 022, Erro: 1.2197, Acurácia: 0.6250
# Treino - Lote número 023, Erro: 0.3884, Acurácia: 0.8750
# Treino - Lote número 024, Erro: 0.2008, Acurácia: 1.0000
# Treino - Lote número 025, Erro: 0.1667, Acurácia: 1.0000
# Treino - Lote número 026, Erro: 0.2408, Acurácia: 0.8750
# Treino - Lote número 027, Erro: 0.2856, Acurácia: 0.8750
# Treino - Lote número 028, Erro: 0.1456, Acurácia: 1.0000
# Treino - Lote número 029, Erro: 0.0872, Acurácia: 1.0000
# Treino - Lote número 030, Erro: 0.0078, Acurácia: 1.0000
# Treino - Lote número 031, Erro: 0.0701, Acurácia: 1.0000
# Treino - Lote número 032, Erro: 0.0295, Acurácia: 1.0000
# Treino - Lote número 033, Erro: 0.1232, Acurácia: 0.8750
# Treino - Lote número 034, Erro: 1.0121, Acurácia: 0.7500
# Treino - Lote número 035, Erro: 0.0550, Acurácia: 1.0000
# Treino - Lote número 036, Erro: 0.5519, Acurácia: 0.7500
# Treino - Lote número 037, Erro: 0.0697, Acurácia: 1.0000
# Treino - Lote número 038, Erro: 0.2665, Acurácia: 0.8750
# Treino - Lote número 039, Erro: 0.1721, Acurácia: 1.0000
# Treino - Lote número 040, Erro: 0.5964, Acurácia: 0.8750
# Treino - Lote número 041, Erro: 0.8522, Acurácia: 0.6250
# Treino - Lote número 042, Erro: 0.2275, Acurácia: 1.0000
# Treino - Lote número 043, Erro: 0.1874, Acurácia: 0.8750
# Treino - Lote número 044, Erro: 0.0850, Acurácia: 1.0000
# Treino - Lote número 045, Erro: 0.3105, Acurácia: 0.8750
# Treino - Lote número 046, Erro: 0.5654, Acurácia: 0.8750
# Treino - Lote número 047, Erro: 0.0681, Acurácia: 1.0000
# Treino - Lote número 048, Erro: 0.0614, Acurácia: 1.0000
# Treino - Lote número 049, Erro: 1.5737, Acurácia: 0.6250
# Treino - Lote número 050, Erro: 0.0772, Acurácia: 1.0000
# Treino - Lote número 051, Erro: 0.1563, Acurácia: 0.8750
# Treino - Lote número 052, Erro: 0.6040, Acurácia: 0.7500
# Treino - Lote número 053, Erro: 0.6958, Acurácia: 0.8750
# Treino - Lote número 054, Erro: 1.8528, Acurácia: 0.5000
# Treino - Lote número 055, Erro: 0.2417, Acurácia: 0.8750
# Treino - Lote número 056, Erro: 0.1515, Acurácia: 0.8750
# Treino - Lote número 057, Erro: 0.2648, Acurácia: 0.8750
# Treino - Lote número 058, Erro: 1.1560, Acurácia: 0.7500
# Treino - Lote número 059, Erro: 0.1379, Acurácia: 1.0000
# Treino - Lote número 060, Erro: 0.1340, Acurácia: 1.0000
# Treino - Lote número 061, Erro: 0.3483, Acurácia: 0.8750
# Treino - Lote número 062, Erro: 0.1088, Acurácia: 1.0000
# Treino - Lote número 063, Erro: 0.3271, Acurácia: 0.8750
# Treino - Lote número 064, Erro: 0.8503, Acurácia: 0.7500
# Treino - Lote número 065, Erro: 0.1060, Acurácia: 1.0000
# Treino - Lote número 066, Erro: 0.3719, Acurácia: 0.8750
# Treino - Lote número 067, Erro: 0.3290, Acurácia: 0.8750
# Treino - Lote número 068, Erro: 0.0807, Acurácia: 1.0000
# Treino - Lote número 069, Erro: 0.0441, Acurácia: 1.0000
# Treino - Lote número 070, Erro: 0.4168, Acurácia: 0.7500
# Treino - Lote número 071, Erro: 0.0175, Acurácia: 1.0000
# Treino - Lote número 072, Erro: 0.1814, Acurácia: 0.8750
# Treino - Lote número 073, Erro: 0.0110, Acurácia: 1.0000
# Treino - Lote número 074, Erro: 0.0794, Acurácia: 1.0000
# Treino - Lote número 075, Erro: 1.0248, Acurácia: 0.7500
# Treino - Lote número 076, Erro: 0.5445, Acurácia: 0.8750
# Treino - Lote número 077, Erro: 0.3398, Acurácia: 0.8750
# Treino - Lote número 078, Erro: 0.0582, Acurácia: 1.0000
# Treino - Lote número 079, Erro: 0.3257, Acurácia: 0.8750
# Treino - Lote número 080, Erro: 0.3363, Acurácia: 0.8750
# Treino - Lote número 081, Erro: 1.3258, Acurácia: 0.7500
# Treino - Lote número 082, Erro: 0.6268, Acurácia: 0.7500
# Treino - Lote número 083, Erro: 1.3300, Acurácia: 0.6250
# Treino - Lote número 084, Erro: 0.1591, Acurácia: 0.8750
# Treino - Lote número 085, Erro: 0.2138, Acurácia: 0.8750
# Treino - Lote número 086, Erro: 0.5994, Acurácia: 0.7500
# Treino - Lote número 087, Erro: 0.1352, Acurácia: 1.0000
# Treino - Lote número 088, Erro: 0.0894, Acurácia: 1.0000
# Treino - Lote número 089, Erro: 0.2281, Acurácia: 0.8750
# Treino - Lote número 090, Erro: 0.8740, Acurácia: 0.7500
# Treino - Lote número 091, Erro: 1.4811, Acurácia: 0.7500
# Treino - Lote número 092, Erro: 0.7684, Acurácia: 0.7500
# Treino - Lote número 093, Erro: 0.0512, Acurácia: 1.0000
# Treino - Lote número 094, Erro: 0.1690, Acurácia: 1.0000
# Treino - Lote número 095, Erro: 0.3226, Acurácia: 0.8750
# Treino - Lote número 096, Erro: 0.1487, Acurácia: 0.8750
# Treino - Lote número 097, Erro: 0.1406, Acurácia: 1.0000
# Treino - Lote número 098, Erro: 0.0289, Acurácia: 1.0000
# Treino - Lote número 099, Erro: 0.1397, Acurácia: 0.8750
# Treino - Lote número 100, Erro: 0.3915, Acurácia: 0.7500
# Treino - Lote número 101, Erro: 0.0797, Acurácia: 1.0000
# Treino - Lote número 102, Erro: 0.6969, Acurácia: 0.7500
# Treino - Lote número 103, Erro: 0.1452, Acurácia: 0.8750
# Treino - Lote número 104, Erro: 0.0232, Acurácia: 1.0000
# Treino - Lote número 105, Erro: 0.4438, Acurácia: 0.8750
# Treino - Lote número 106, Erro: 0.0737, Acurácia: 1.0000
# Treino - Lote número 107, Erro: 0.4249, Acurácia: 0.7500
# Treino - Lote número 108, Erro: 0.1572, Acurácia: 0.8750
# Treino - Lote número 109, Erro: 0.8278, Acurácia: 0.6250
# Treino - Lote número 110, Erro: 0.0067, Acurácia: 1.0000
# Treino - Lote número 111, Erro: 0.3515, Acurácia: 0.8750
# Treino - Lote número 112, Erro: 0.0153, Acurácia: 1.0000
# Treino - Lote número 113, Erro: 0.1457, Acurácia: 1.0000
# Treino - Lote número 114, Erro: 0.2138, Acurácia: 0.8750
# Treino - Lote número 115, Erro: 0.0973, Acurácia: 1.0000
# Treino - Lote número 116, Erro: 0.2618, Acurácia: 0.8750
# Treino - Lote número 117, Erro: 0.3354, Acurácia: 0.8750
# Treino - Lote número 118, Erro: 0.0533, Acurácia: 1.0000
# Treino - Lote número 119, Erro: 0.1013, Acurácia: 1.0000
# Treino - Lote número 120, Erro: 0.4870, Acurácia: 0.8750
# Treino - Lote número 121, Erro: 0.2528, Acurácia: 0.8750
# Treino - Lote número 122, Erro: 0.8747, Acurácia: 0.7500
# Treino - Lote número 123, Erro: 0.2092, Acurácia: 0.8750
# Treino - Lote número 124, Erro: 0.0388, Acurácia: 1.0000
# Treino - Lote número 125, Erro: 0.2209, Acurácia: 0.8750
# Treino - Lote número 126, Erro: 0.0371, Acurácia: 1.0000
# Treino - Lote número 127, Erro: 0.2184, Acurácia: 0.8750
# Treino - Lote número 128, Erro: 0.2513, Acurácia: 0.8750
# Treino - Lote número 129, Erro: 0.0960, Acurácia: 1.0000
# Treino - Lote número 130, Erro: 0.8297, Acurácia: 0.8750
# Treino - Lote número 131, Erro: 0.3110, Acurácia: 0.8750
# Treino - Lote número 132, Erro: 0.6116, Acurácia: 0.8750
# Treino - Lote número 133, Erro: 0.1290, Acurácia: 1.0000
# Treino - Lote número 134, Erro: 0.0961, Acurácia: 1.0000
# Treino - Lote número 135, Erro: 0.1519, Acurácia: 1.0000
# Treino - Lote número 136, Erro: 0.2802, Acurácia: 0.8750
# Treino - Lote número 137, Erro: 0.0486, Acurácia: 1.0000
# Treino - Lote número 138, Erro: 0.1250, Acurácia: 1.0000
# Treino - Lote número 139, Erro: 0.5528, Acurácia: 0.6250
# Treino - Lote número 140, Erro: 0.1216, Acurácia: 0.8750
# Treino - Lote número 141, Erro: 0.5352, Acurácia: 0.7500
# Treino - Lote número 142, Erro: 0.0319, Acurácia: 1.0000
# Treino - Lote número 143, Erro: 0.1929, Acurácia: 0.8750
# Treino - Lote número 144, Erro: 0.6926, Acurácia: 0.6250
# Treino - Lote número 145, Erro: 0.6320, Acurácia: 0.7500
# Treino - Lote número 146, Erro: 0.3115, Acurácia: 0.8750
# Treino - Lote número 147, Erro: 0.2262, Acurácia: 1.0000
# Treino - Lote número 148, Erro: 0.1400, Acurácia: 1.0000
# Treino - Lote número 149, Erro: 0.0509, Acurácia: 1.0000
# Treino - Lote número 150, Erro: 0.1117, Acurácia: 1.0000
# Treino - Lote número 151, Erro: 0.0591, Acurácia: 1.0000
# Treino - Lote número 152, Erro: 0.5658, Acurácia: 0.7500
# Treino - Lote número 153, Erro: 0.0137, Acurácia: 1.0000
# Treino - Lote número 154, Erro: 0.9764, Acurácia: 0.6250
# Treino - Lote número 155, Erro: 0.0860, Acurácia: 1.0000
# Treino - Lote número 156, Erro: 0.0587, Acurácia: 1.0000
# Treino - Lote número 157, Erro: 0.1511, Acurácia: 0.8750
# Treino - Lote número 158, Erro: 0.0814, Acurácia: 1.0000
# Treino - Lote número 159, Erro: 0.5010, Acurácia: 0.8750
# Treino - Lote número 160, Erro: 0.0125, Acurácia: 1.0000
# Treino - Lote número 161, Erro: 0.1808, Acurácia: 0.8750
# Treino - Lote número 162, Erro: 0.4906, Acurácia: 0.8750
# Treino - Lote número 163, Erro: 0.0132, Acurácia: 1.0000
# Treino - Lote número 164, Erro: 0.1050, Acurácia: 1.0000
# Treino - Lote número 165, Erro: 0.0693, Acurácia: 1.0000
# Treino - Lote número 166, Erro: 0.3537, Acurácia: 0.8750
# Treino - Lote número 167, Erro: 0.1020, Acurácia: 0.8750
# Treino - Lote número 168, Erro: 0.4621, Acurácia: 0.8750
# Treino - Lote número 169, Erro: 0.1909, Acurácia: 0.8750
# Treino - Lote número 170, Erro: 0.3201, Acurácia: 0.7500
# Treino - Lote número 171, Erro: 0.2250, Acurácia: 0.8750
# Treino - Lote número 172, Erro: 0.8805, Acurácia: 0.7500
# Treino - Lote número 173, Erro: 0.0665, Acurácia: 1.0000
# Treino - Lote número 174, Erro: 0.3467, Acurácia: 0.8750
# Treino - Lote número 175, Erro: 0.0609, Acurácia: 1.0000
# Treino - Lote número 176, Erro: 0.3406, Acurácia: 0.6250
# Treino - Lote número 177, Erro: 0.0706, Acurácia: 1.0000
# Treino - Lote número 178, Erro: 0.0180, Acurácia: 1.0000
# Treino - Lote número 179, Erro: 0.1847, Acurácia: 1.0000
# Treino - Lote número 180, Erro: 0.0700, Acurácia: 1.0000
# Treino - Lote número 181, Erro: 0.5349, Acurácia: 0.6250
# Treino - Lote número 182, Erro: 0.0997, Acurácia: 1.0000
# Treino - Lote número 183, Erro: 0.1814, Acurácia: 0.8750
# Treino - Lote número 184, Erro: 0.1784, Acurácia: 0.8750
# Treino - Lote número 185, Erro: 1.3268, Acurácia: 0.6250
# Treino - Lote número 186, Erro: 0.4668, Acurácia: 0.7500
# Treino - Lote número 187, Erro: 0.6990, Acurácia: 0.7500
# Treino - Lote número 188, Erro: 0.4513, Acurácia: 0.7500
# Treino - Lote número 189, Erro: 1.4326, Acurácia: 0.7500
# Treino - Lote número 190, Erro: 0.2823, Acurácia: 0.8750
# Treino - Lote número 191, Erro: 0.0074, Acurácia: 1.0000
# Treino - Lote número 192, Erro: 0.1439, Acurácia: 0.8750
# Treino - Lote número 193, Erro: 0.4950, Acurácia: 0.6250
# Treino - Lote número 194, Erro: 0.2231, Acurácia: 0.8750
# Treino - Lote número 195, Erro: 0.4446, Acurácia: 0.7500
# Treino - Lote número 196, Erro: 0.0559, Acurácia: 1.0000
# Treino - Lote número 197, Erro: 0.1866, Acurácia: 0.8750
# Treino - Lote número 198, Erro: 0.0544, Acurácia: 1.0000
# Treino - Lote número 199, Erro: 0.7511, Acurácia: 0.7500
# Treino - Lote número 200, Erro: 0.0405, Acurácia: 1.0000
# Treino - Lote número 201, Erro: 0.0658, Acurácia: 1.0000
# Validação - Lote número: 000, Erro: 0.7837, Acurácia: 0.7500
# Validação - Lote número: 001, Erro: 0.6471, Acurácia: 0.8750
# Validação - Lote número: 002, Erro: 1.1445, Acurácia: 0.6250
# Validação - Lote número: 003, Erro: 1.8566, Acurácia: 0.3333
# Época : 003, Treino: Erro: 0.3201, Acurácia: 88.9233%,
# 		Validação : Erro : 0.9694, Acurácia: 70.3704%, Tempo: 11.6508s
#
#
# Época: 4/20
# Treino - Lote número 000, Erro: 0.7471, Acurácia: 0.6250
# Treino - Lote número 001, Erro: 0.7221, Acurácia: 0.7500
# Treino - Lote número 002, Erro: 0.0440, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.0448, Acurácia: 1.0000
# Treino - Lote número 004, Erro: 0.1810, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.3864, Acurácia: 0.7500
# Treino - Lote número 006, Erro: 0.0497, Acurácia: 1.0000
# Treino - Lote número 007, Erro: 0.1311, Acurácia: 0.8750
# Treino - Lote número 008, Erro: 0.4770, Acurácia: 0.8750
# Treino - Lote número 009, Erro: 0.0657, Acurácia: 1.0000
# Treino - Lote número 010, Erro: 0.0192, Acurácia: 1.0000
# Treino - Lote número 011, Erro: 0.0956, Acurácia: 1.0000
# Treino - Lote número 012, Erro: 0.5278, Acurácia: 0.8750
# Treino - Lote número 013, Erro: 0.1251, Acurácia: 1.0000
# Treino - Lote número 014, Erro: 0.4310, Acurácia: 0.7500
# Treino - Lote número 015, Erro: 0.0517, Acurácia: 1.0000
# Treino - Lote número 016, Erro: 0.0772, Acurácia: 1.0000
# Treino - Lote número 017, Erro: 0.4656, Acurácia: 0.8750
# Treino - Lote número 018, Erro: 0.5977, Acurácia: 0.8750
# Treino - Lote número 019, Erro: 0.3212, Acurácia: 0.7500
# Treino - Lote número 020, Erro: 0.5391, Acurácia: 0.6250
# Treino - Lote número 021, Erro: 0.3262, Acurácia: 0.8750
# Treino - Lote número 022, Erro: 0.3161, Acurácia: 0.8750
# Treino - Lote número 023, Erro: 0.0568, Acurácia: 1.0000
# Treino - Lote número 024, Erro: 0.1309, Acurácia: 1.0000
# Treino - Lote número 025, Erro: 0.6657, Acurácia: 0.7500
# Treino - Lote número 026, Erro: 0.3919, Acurácia: 0.7500
# Treino - Lote número 027, Erro: 0.9845, Acurácia: 0.5000
# Treino - Lote número 028, Erro: 0.6018, Acurácia: 0.7500
# Treino - Lote número 029, Erro: 0.1630, Acurácia: 1.0000
# Treino - Lote número 030, Erro: 0.6894, Acurácia: 0.7500
# Treino - Lote número 031, Erro: 0.4604, Acurácia: 0.8750
# Treino - Lote número 032, Erro: 0.2338, Acurácia: 0.8750
# Treino - Lote número 033, Erro: 0.1221, Acurácia: 1.0000
# Treino - Lote número 034, Erro: 0.1371, Acurácia: 1.0000
# Treino - Lote número 035, Erro: 0.3260, Acurácia: 0.8750
# Treino - Lote número 036, Erro: 0.0012, Acurácia: 1.0000
# Treino - Lote número 037, Erro: 0.0160, Acurácia: 1.0000
# Treino - Lote número 038, Erro: 0.0752, Acurácia: 1.0000
# Treino - Lote número 039, Erro: 0.0004, Acurácia: 1.0000
# Treino - Lote número 040, Erro: 0.1168, Acurácia: 0.8750
# Treino - Lote número 041, Erro: 0.2077, Acurácia: 0.8750
# Treino - Lote número 042, Erro: 1.0183, Acurácia: 0.7500
# Treino - Lote número 043, Erro: 0.1393, Acurácia: 0.8750
# Treino - Lote número 044, Erro: 0.7240, Acurácia: 0.8750
# Treino - Lote número 045, Erro: 0.0586, Acurácia: 1.0000
# Treino - Lote número 046, Erro: 0.0466, Acurácia: 1.0000
# Treino - Lote número 047, Erro: 0.3364, Acurácia: 0.7500
# Treino - Lote número 048, Erro: 0.5389, Acurácia: 0.7500
# Treino - Lote número 049, Erro: 0.1863, Acurácia: 1.0000
# Treino - Lote número 050, Erro: 0.8854, Acurácia: 0.8750
# Treino - Lote número 051, Erro: 0.2090, Acurácia: 0.8750
# Treino - Lote número 052, Erro: 0.5880, Acurácia: 0.8750
# Treino - Lote número 053, Erro: 0.2700, Acurácia: 0.8750
# Treino - Lote número 054, Erro: 0.1302, Acurácia: 1.0000
# Treino - Lote número 055, Erro: 0.2646, Acurácia: 0.8750
# Treino - Lote número 056, Erro: 0.1056, Acurácia: 0.8750
# Treino - Lote número 057, Erro: 0.0086, Acurácia: 1.0000
# Treino - Lote número 058, Erro: 0.0645, Acurácia: 1.0000
# Treino - Lote número 059, Erro: 0.8135, Acurácia: 0.7500
# Treino - Lote número 060, Erro: 0.5029, Acurácia: 0.8750
# Treino - Lote número 061, Erro: 0.0112, Acurácia: 1.0000
# Treino - Lote número 062, Erro: 0.5315, Acurácia: 0.8750
# Treino - Lote número 063, Erro: 0.0112, Acurácia: 1.0000
# Treino - Lote número 064, Erro: 0.0733, Acurácia: 1.0000
# Treino - Lote número 065, Erro: 0.0062, Acurácia: 1.0000
# Treino - Lote número 066, Erro: 0.3318, Acurácia: 0.8750
# Treino - Lote número 067, Erro: 0.3821, Acurácia: 0.7500
# Treino - Lote número 068, Erro: 0.0109, Acurácia: 1.0000
# Treino - Lote número 069, Erro: 0.2593, Acurácia: 0.8750
# Treino - Lote número 070, Erro: 0.1112, Acurácia: 1.0000
# Treino - Lote número 071, Erro: 0.3073, Acurácia: 0.7500
# Treino - Lote número 072, Erro: 0.8413, Acurácia: 0.8750
# Treino - Lote número 073, Erro: 0.2372, Acurácia: 0.8750
# Treino - Lote número 074, Erro: 0.6617, Acurácia: 0.8750
# Treino - Lote número 075, Erro: 0.0901, Acurácia: 1.0000
# Treino - Lote número 076, Erro: 0.1010, Acurácia: 1.0000
# Treino - Lote número 077, Erro: 0.7578, Acurácia: 0.8750
# Treino - Lote número 078, Erro: 0.3914, Acurácia: 0.8750
# Treino - Lote número 079, Erro: 0.1717, Acurácia: 0.8750
# Treino - Lote número 080, Erro: 0.1749, Acurácia: 0.8750
# Treino - Lote número 081, Erro: 0.6104, Acurácia: 0.7500
# Treino - Lote número 082, Erro: 0.0637, Acurácia: 1.0000
# Treino - Lote número 083, Erro: 0.2892, Acurácia: 0.8750
# Treino - Lote número 084, Erro: 0.4174, Acurácia: 0.8750
# Treino - Lote número 085, Erro: 0.1118, Acurácia: 1.0000
# Treino - Lote número 086, Erro: 0.1588, Acurácia: 0.8750
# Treino - Lote número 087, Erro: 0.4272, Acurácia: 0.8750
# Treino - Lote número 088, Erro: 0.3768, Acurácia: 0.8750
# Treino - Lote número 089, Erro: 0.2080, Acurácia: 0.8750
# Treino - Lote número 090, Erro: 0.0329, Acurácia: 1.0000
# Treino - Lote número 091, Erro: 0.0751, Acurácia: 1.0000
# Treino - Lote número 092, Erro: 0.0409, Acurácia: 1.0000
# Treino - Lote número 093, Erro: 0.3151, Acurácia: 0.8750
# Treino - Lote número 094, Erro: 0.0561, Acurácia: 1.0000
# Treino - Lote número 095, Erro: 0.4056, Acurácia: 0.7500
# Treino - Lote número 096, Erro: 0.3729, Acurácia: 0.7500
# Treino - Lote número 097, Erro: 0.3018, Acurácia: 0.8750
# Treino - Lote número 098, Erro: 0.3287, Acurácia: 0.8750
# Treino - Lote número 099, Erro: 0.1519, Acurácia: 0.8750
# Treino - Lote número 100, Erro: 0.0679, Acurácia: 1.0000
# Treino - Lote número 101, Erro: 0.3064, Acurácia: 0.7500
# Treino - Lote número 102, Erro: 0.0981, Acurácia: 1.0000
# Treino - Lote número 103, Erro: 0.0097, Acurácia: 1.0000
# Treino - Lote número 104, Erro: 0.0287, Acurácia: 1.0000
# Treino - Lote número 105, Erro: 0.0542, Acurácia: 1.0000
# Treino - Lote número 106, Erro: 0.5011, Acurácia: 0.8750
# Treino - Lote número 107, Erro: 0.1329, Acurácia: 1.0000
# Treino - Lote número 108, Erro: 0.0408, Acurácia: 1.0000
# Treino - Lote número 109, Erro: 0.1955, Acurácia: 0.8750
# Treino - Lote número 110, Erro: 0.0342, Acurácia: 1.0000
# Treino - Lote número 111, Erro: 0.4485, Acurácia: 0.8750
# Treino - Lote número 112, Erro: 0.0299, Acurácia: 1.0000
# Treino - Lote número 113, Erro: 0.2217, Acurácia: 0.8750
# Treino - Lote número 114, Erro: 0.2298, Acurácia: 0.8750
# Treino - Lote número 115, Erro: 0.0352, Acurácia: 1.0000
# Treino - Lote número 116, Erro: 0.1454, Acurácia: 0.8750
# Treino - Lote número 117, Erro: 0.3517, Acurácia: 0.7500
# Treino - Lote número 118, Erro: 0.1265, Acurácia: 0.8750
# Treino - Lote número 119, Erro: 0.0432, Acurácia: 1.0000
# Treino - Lote número 120, Erro: 0.0315, Acurácia: 1.0000
# Treino - Lote número 121, Erro: 0.0261, Acurácia: 1.0000
# Treino - Lote número 122, Erro: 0.4513, Acurácia: 0.8750
# Treino - Lote número 123, Erro: 1.5719, Acurácia: 0.7500
# Treino - Lote número 124, Erro: 0.0619, Acurácia: 1.0000
# Treino - Lote número 125, Erro: 0.1343, Acurácia: 0.8750
# Treino - Lote número 126, Erro: 0.1738, Acurácia: 0.8750
# Treino - Lote número 127, Erro: 0.0104, Acurácia: 1.0000
# Treino - Lote número 128, Erro: 0.4682, Acurácia: 0.7500
# Treino - Lote número 129, Erro: 0.1712, Acurácia: 0.8750
# Treino - Lote número 130, Erro: 1.2882, Acurácia: 0.7500
# Treino - Lote número 131, Erro: 0.0084, Acurácia: 1.0000
# Treino - Lote número 132, Erro: 0.0926, Acurácia: 1.0000
# Treino - Lote número 133, Erro: 0.3909, Acurácia: 0.8750
# Treino - Lote número 134, Erro: 0.5109, Acurácia: 0.8750
# Treino - Lote número 135, Erro: 0.4447, Acurácia: 0.8750
# Treino - Lote número 136, Erro: 0.0511, Acurácia: 1.0000
# Treino - Lote número 137, Erro: 0.3740, Acurácia: 0.8750
# Treino - Lote número 138, Erro: 0.4490, Acurácia: 0.7500
# Treino - Lote número 139, Erro: 0.0604, Acurácia: 1.0000
# Treino - Lote número 140, Erro: 0.4531, Acurácia: 0.7500
# Treino - Lote número 141, Erro: 0.5135, Acurácia: 0.8750
# Treino - Lote número 142, Erro: 0.3052, Acurácia: 0.8750
# Treino - Lote número 143, Erro: 0.2219, Acurácia: 0.8750
# Treino - Lote número 144, Erro: 0.0106, Acurácia: 1.0000
# Treino - Lote número 145, Erro: 0.6091, Acurácia: 0.8750
# Treino - Lote número 146, Erro: 0.7537, Acurácia: 0.7500
# Treino - Lote número 147, Erro: 0.4842, Acurácia: 0.8750
# Treino - Lote número 148, Erro: 0.1354, Acurácia: 0.8750
# Treino - Lote número 149, Erro: 0.2517, Acurácia: 0.8750
# Treino - Lote número 150, Erro: 0.0565, Acurácia: 1.0000
# Treino - Lote número 151, Erro: 0.0906, Acurácia: 1.0000
# Treino - Lote número 152, Erro: 1.3109, Acurácia: 0.6250
# Treino - Lote número 153, Erro: 0.0103, Acurácia: 1.0000
# Treino - Lote número 154, Erro: 0.0536, Acurácia: 1.0000
# Treino - Lote número 155, Erro: 2.2095, Acurácia: 0.7500
# Treino - Lote número 156, Erro: 0.4234, Acurácia: 0.8750
# Treino - Lote número 157, Erro: 0.6456, Acurácia: 0.7500
# Treino - Lote número 158, Erro: 0.6038, Acurácia: 0.8750
# Treino - Lote número 159, Erro: 0.0097, Acurácia: 1.0000
# Treino - Lote número 160, Erro: 1.1620, Acurácia: 0.6250
# Treino - Lote número 161, Erro: 0.4915, Acurácia: 0.8750
# Treino - Lote número 162, Erro: 0.4596, Acurácia: 0.6250
# Treino - Lote número 163, Erro: 0.0321, Acurácia: 1.0000
# Treino - Lote número 164, Erro: 0.9116, Acurácia: 0.6250
# Treino - Lote número 165, Erro: 0.3744, Acurácia: 0.8750
# Treino - Lote número 166, Erro: 0.7656, Acurácia: 0.6250
# Treino - Lote número 167, Erro: 0.2873, Acurácia: 0.7500
# Treino - Lote número 168, Erro: 0.8405, Acurácia: 0.5000
# Treino - Lote número 169, Erro: 0.9795, Acurácia: 0.7500
# Treino - Lote número 170, Erro: 0.3657, Acurácia: 0.7500
# Treino - Lote número 171, Erro: 0.1564, Acurácia: 0.8750
# Treino - Lote número 172, Erro: 0.1532, Acurácia: 0.8750
# Treino - Lote número 173, Erro: 0.0152, Acurácia: 1.0000
# Treino - Lote número 174, Erro: 0.6306, Acurácia: 0.8750
# Treino - Lote número 175, Erro: 1.4136, Acurácia: 0.7500
# Treino - Lote número 176, Erro: 0.1730, Acurácia: 0.8750
# Treino - Lote número 177, Erro: 1.0482, Acurácia: 0.7500
# Treino - Lote número 178, Erro: 0.0999, Acurácia: 1.0000
# Treino - Lote número 179, Erro: 0.9345, Acurácia: 0.7500
# Treino - Lote número 180, Erro: 0.1279, Acurácia: 1.0000
# Treino - Lote número 181, Erro: 0.2331, Acurácia: 0.8750
# Treino - Lote número 182, Erro: 0.7098, Acurácia: 0.8750
# Treino - Lote número 183, Erro: 0.0894, Acurácia: 1.0000
# Treino - Lote número 184, Erro: 0.0621, Acurácia: 1.0000
# Treino - Lote número 185, Erro: 0.5690, Acurácia: 0.7500
# Treino - Lote número 186, Erro: 0.1468, Acurácia: 1.0000
# Treino - Lote número 187, Erro: 0.7233, Acurácia: 0.6250
# Treino - Lote número 188, Erro: 0.2529, Acurácia: 1.0000
# Treino - Lote número 189, Erro: 0.0718, Acurácia: 1.0000
# Treino - Lote número 190, Erro: 0.2783, Acurácia: 0.7500
# Treino - Lote número 191, Erro: 0.0108, Acurácia: 1.0000
# Treino - Lote número 192, Erro: 0.0064, Acurácia: 1.0000
# Treino - Lote número 193, Erro: 1.0716, Acurácia: 0.7500
# Treino - Lote número 194, Erro: 0.2527, Acurácia: 0.8750
# Treino - Lote número 195, Erro: 1.1621, Acurácia: 0.5000
# Treino - Lote número 196, Erro: 0.0106, Acurácia: 1.0000
# Treino - Lote número 197, Erro: 0.1795, Acurácia: 0.8750
# Treino - Lote número 198, Erro: 1.9515, Acurácia: 0.7500
# Treino - Lote número 199, Erro: 0.0376, Acurácia: 1.0000
# Treino - Lote número 200, Erro: 0.1924, Acurácia: 0.8750
# Treino - Lote número 201, Erro: 0.5878, Acurácia: 0.6250
# Validação - Lote número: 000, Erro: 1.0659, Acurácia: 0.5000
# Validação - Lote número: 001, Erro: 0.2313, Acurácia: 0.8750
# Validação - Lote número: 002, Erro: 0.6012, Acurácia: 0.8750
# Validação - Lote número: 003, Erro: 1.5205, Acurácia: 0.6667
# Época : 004, Treino: Erro: 0.3380, Acurácia: 88.2426%,
# 		Validação : Erro : 0.7315, Acurácia: 74.0741%, Tempo: 11.3045s
#
#
# Época: 5/20
# Treino - Lote número 000, Erro: 0.0239, Acurácia: 1.0000
# Treino - Lote número 001, Erro: 0.1073, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.6879, Acurácia: 0.7500
# Treino - Lote número 003, Erro: 0.2833, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.2119, Acurácia: 1.0000
# Treino - Lote número 005, Erro: 0.0264, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.0325, Acurácia: 1.0000
# ...
# Treino - Lote número 137, Erro: 0.1372, Acurácia: 1.0000
# Treino - Lote número 138, Erro: 0.0347, Acurácia: 1.0000
# Treino - Lote número 139, Erro: 0.2657, Acurácia: 0.8750
# Treino - Lote número 140, Erro: 0.0114, Acurácia: 1.0000
# Treino - Lote número 141, Erro: 0.5831, Acurácia: 0.8750
# Treino - Lote número 142, Erro: 1.1761, Acurácia: 0.7500
# Treino - Lote número 143, Erro: 0.1754, Acurácia: 0.8750
# Treino - Lote número 144, Erro: 1.0326, Acurácia: 0.8750
# Treino - Lote número 145, Erro: 0.0066, Acurácia: 1.0000
# Treino - Lote número 146, Erro: 1.7716, Acurácia: 0.7500
# Treino - Lote número 147, Erro: 0.3343, Acurácia: 0.8750
# Treino - Lote número 148, Erro: 0.1373, Acurácia: 0.8750
# Treino - Lote número 149, Erro: 0.0329, Acurácia: 1.0000
# Treino - Lote número 150, Erro: 0.0445, Acurácia: 1.0000
# Treino - Lote número 151, Erro: 0.0045, Acurácia: 1.0000
# Treino - Lote número 152, Erro: 0.0685, Acurácia: 1.0000
# Treino - Lote número 153, Erro: 0.0036, Acurácia: 1.0000
# Treino - Lote número 154, Erro: 0.1635, Acurácia: 0.8750
# Treino - Lote número 155, Erro: 0.2556, Acurácia: 0.8750
# Treino - Lote número 156, Erro: 1.0399, Acurácia: 0.7500
# Treino - Lote número 157, Erro: 0.0026, Acurácia: 1.0000
# Treino - Lote número 158, Erro: 0.2072, Acurácia: 0.8750
# Treino - Lote número 159, Erro: 0.3629, Acurácia: 0.8750
# Treino - Lote número 160, Erro: 0.1639, Acurácia: 0.8750
# Treino - Lote número 161, Erro: 0.9531, Acurácia: 0.7500
# Treino - Lote número 162, Erro: 0.3415, Acurácia: 0.8750
# Treino - Lote número 163, Erro: 1.4025, Acurácia: 0.7500
# Treino - Lote número 164, Erro: 0.1018, Acurácia: 1.0000
# Treino - Lote número 165, Erro: 1.1875, Acurácia: 0.6250
# Treino - Lote número 166, Erro: 0.5558, Acurácia: 0.6250
# Treino - Lote número 167, Erro: 0.2813, Acurácia: 0.8750
# Treino - Lote número 168, Erro: 0.0952, Acurácia: 1.0000
# Treino - Lote número 169, Erro: 0.1981, Acurácia: 0.8750
# Treino - Lote número 170, Erro: 0.2851, Acurácia: 0.8750
# Treino - Lote número 171, Erro: 0.0041, Acurácia: 1.0000
# Treino - Lote número 172, Erro: 0.0762, Acurácia: 1.0000
# Treino - Lote número 173, Erro: 0.0505, Acurácia: 1.0000
# Treino - Lote número 174, Erro: 1.2481, Acurácia: 0.8750
# Treino - Lote número 175, Erro: 0.0659, Acurácia: 1.0000
# Treino - Lote número 176, Erro: 0.0535, Acurácia: 1.0000
# Treino - Lote número 177, Erro: 0.0063, Acurácia: 1.0000
# Treino - Lote número 178, Erro: 0.0167, Acurácia: 1.0000
# Treino - Lote número 179, Erro: 0.8251, Acurácia: 0.8750
# Treino - Lote número 180, Erro: 0.5365, Acurácia: 0.6250
# Treino - Lote número 181, Erro: 0.0238, Acurácia: 1.0000
# Treino - Lote número 182, Erro: 0.7834, Acurácia: 0.7500
# Treino - Lote número 183, Erro: 0.1974, Acurácia: 0.8750
# Treino - Lote número 184, Erro: 0.6062, Acurácia: 0.7500
# Treino - Lote número 185, Erro: 0.1011, Acurácia: 1.0000
# Treino - Lote número 186, Erro: 0.4860, Acurácia: 0.8750
# Treino - Lote número 187, Erro: 0.5282, Acurácia: 0.6250
# Treino - Lote número 188, Erro: 1.0310, Acurácia: 0.7500
# Treino - Lote número 189, Erro: 0.0143, Acurácia: 1.0000
# Treino - Lote número 190, Erro: 1.2192, Acurácia: 0.5000
# Treino - Lote número 191, Erro: 0.6993, Acurácia: 0.8750
# Treino - Lote número 192, Erro: 0.6212, Acurácia: 0.8750
# Treino - Lote número 193, Erro: 0.0620, Acurácia: 1.0000
# Treino - Lote número 194, Erro: 0.2793, Acurácia: 0.8750
# Treino - Lote número 195, Erro: 0.0397, Acurácia: 1.0000
# Treino - Lote número 196, Erro: 0.6323, Acurácia: 0.8750
# Treino - Lote número 197, Erro: 0.5225, Acurácia: 0.8750
# Treino - Lote número 198, Erro: 0.0186, Acurácia: 1.0000
# Treino - Lote número 199, Erro: 0.4533, Acurácia: 0.8750
# Treino - Lote número 200, Erro: 0.1052, Acurácia: 0.8750
# Treino - Lote número 201, Erro: 0.8939, Acurácia: 0.7500
# Validação - Lote número: 000, Erro: 1.3450, Acurácia: 0.7500
# Validação - Lote número: 001, Erro: 0.2988, Acurácia: 0.8750
# Validação - Lote número: 002, Erro: 1.0654, Acurácia: 0.8750
# Validação - Lote número: 003, Erro: 4.0217, Acurácia: 0.3333
# Época : 019, Treino: Erro: 0.2693, Acurácia: 91.8317%,
# 		Validação : Erro : 1.2496, Acurácia: 77.7778%, Tempo: 11.2906s
#
#
# Época: 20/20
# Treino - Lote número 000, Erro: 0.4399, Acurácia: 0.7500
# Treino - Lote número 001, Erro: 0.0379, Acurácia: 1.0000
# Treino - Lote número 002, Erro: 0.0161, Acurácia: 1.0000
# Treino - Lote número 003, Erro: 0.2161, Acurácia: 0.8750
# Treino - Lote número 004, Erro: 0.7573, Acurácia: 0.8750
# Treino - Lote número 005, Erro: 0.1309, Acurácia: 1.0000
# Treino - Lote número 006, Erro: 0.0820, Acurácia: 1.0000
# Treino - Lote número 007, Erro: 0.5258, Acurácia: 0.8750
# Treino - Lote número 008, Erro: 0.5246, Acurácia: 0.7500
# Treino - Lote número 009, Erro: 1.3347, Acurácia: 0.5000
# Treino - Lote número 010, Erro: 0.0143, Acurácia: 1.0000
# Treino - Lote número 011, Erro: 1.5258, Acurácia: 0.7500
# Treino - Lote número 012, Erro: 1.1058, Acurácia: 0.7500
# Treino - Lote número 013, Erro: 0.0048, Acurácia: 1.0000
# Treino - Lote número 014, Erro: 0.8452, Acurácia: 0.8750
# Treino - Lote número 015, Erro: 0.2714, Acurácia: 0.8750
# Treino - Lote número 016, Erro: 0.3399, Acurácia: 0.8750
# Treino - Lote número 017, Erro: 0.4646, Acurácia: 0.8750
# Treino - Lote número 018, Erro: 0.0441, Acurácia: 1.0000
# Treino - Lote número 019, Erro: 0.1019, Acurácia: 0.8750
# Treino - Lote número 020, Erro: 0.6145, Acurácia: 0.8750
# Treino - Lote número 021, Erro: 0.8365, Acurácia: 0.7500
# Treino - Lote número 022, Erro: 0.2595, Acurácia: 0.7500
# Treino - Lote número 023, Erro: 0.1987, Acurácia: 0.8750
# Treino - Lote número 024, Erro: 0.3161, Acurácia: 0.8750
# Treino - Lote número 025, Erro: 0.3081, Acurácia: 0.8750
# Treino - Lote número 026, Erro: 0.5088, Acurácia: 0.6250
# Treino - Lote número 027, Erro: 0.6862, Acurácia: 0.8750
# Treino - Lote número 028, Erro: 0.2968, Acurácia: 0.8750
# Treino - Lote número 029, Erro: 0.0593, Acurácia: 1.0000
# Treino - Lote número 030, Erro: 0.0334, Acurácia: 1.0000
# Treino - Lote número 031, Erro: 0.0090, Acurácia: 1.0000
# Treino - Lote número 032, Erro: 0.0377, Acurácia: 1.0000
# Treino - Lote número 033, Erro: 0.0037, Acurácia: 1.0000
# Treino - Lote número 034, Erro: 0.0127, Acurácia: 1.0000
# Treino - Lote número 035, Erro: 0.0807, Acurácia: 1.0000
# Treino - Lote número 036, Erro: 0.0980, Acurácia: 0.8750
# Treino - Lote número 037, Erro: 1.4071, Acurácia: 0.8750
# Treino - Lote número 038, Erro: 0.0002, Acurácia: 1.0000
# Treino - Lote número 039, Erro: 0.0256, Acurácia: 1.0000
# Treino - Lote número 040, Erro: 0.6717, Acurácia: 0.8750
# Treino - Lote número 041, Erro: 1.0734, Acurácia: 0.8750
# Treino - Lote número 042, Erro: 0.0052, Acurácia: 1.0000
# Treino - Lote número 043, Erro: 0.6602, Acurácia: 0.8750
# Treino - Lote número 044, Erro: 0.0770, Acurácia: 1.0000
# Treino - Lote número 045, Erro: 0.0380, Acurácia: 1.0000
# Treino - Lote número 046, Erro: 0.0866, Acurácia: 1.0000
# Treino - Lote número 047, Erro: 0.0161, Acurácia: 1.0000
# Treino - Lote número 048, Erro: 0.0031, Acurácia: 1.0000
# Treino - Lote número 049, Erro: 0.5470, Acurácia: 0.8750
# Treino - Lote número 050, Erro: 0.2556, Acurácia: 0.8750
# Treino - Lote número 051, Erro: 0.5827, Acurácia: 0.7500
# Treino - Lote número 052, Erro: 0.0065, Acurácia: 1.0000
# Treino - Lote número 053, Erro: 0.4332, Acurácia: 0.8750
# Treino - Lote número 054, Erro: 0.1293, Acurácia: 1.0000
# Treino - Lote número 055, Erro: 0.0303, Acurácia: 1.0000
# Treino - Lote número 056, Erro: 0.0315, Acurácia: 1.0000
# Treino - Lote número 057, Erro: 0.0339, Acurácia: 1.0000
# Treino - Lote número 058, Erro: 0.0300, Acurácia: 1.0000
# Treino - Lote número 059, Erro: 0.0404, Acurácia: 1.0000
# Treino - Lote número 060, Erro: 0.1026, Acurácia: 1.0000
# Treino - Lote número 061, Erro: 0.2322, Acurácia: 0.8750
# Treino - Lote número 062, Erro: 0.2626, Acurácia: 0.8750
# Treino - Lote número 063, Erro: 0.2150, Acurácia: 0.8750
# Treino - Lote número 064, Erro: 0.1138, Acurácia: 1.0000
# Treino - Lote número 065, Erro: 0.0775, Acurácia: 1.0000
# Treino - Lote número 066, Erro: 0.0409, Acurácia: 1.0000
# Treino - Lote número 067, Erro: 0.0339, Acurácia: 1.0000
# Treino - Lote número 068, Erro: 0.1457, Acurácia: 0.8750
# Treino - Lote número 069, Erro: 1.3746, Acurácia: 0.6250
# Treino - Lote número 070, Erro: 0.3822, Acurácia: 0.8750
# Treino - Lote número 071, Erro: 0.0309, Acurácia: 1.0000
# Treino - Lote número 072, Erro: 0.0486, Acurácia: 1.0000
# Treino - Lote número 073, Erro: 0.0019, Acurácia: 1.0000
# Treino - Lote número 074, Erro: 0.0870, Acurácia: 1.0000
# Treino - Lote número 075, Erro: 0.0005, Acurácia: 1.0000
# Treino - Lote número 076, Erro: 0.1315, Acurácia: 1.0000
# Treino - Lote número 077, Erro: 0.0121, Acurácia: 1.0000
# Treino - Lote número 078, Erro: 0.0271, Acurácia: 1.0000
# Treino - Lote número 079, Erro: 0.0665, Acurácia: 1.0000
# Treino - Lote número 080, Erro: 0.4785, Acurácia: 0.8750
# Treino - Lote número 081, Erro: 0.0808, Acurácia: 1.0000
# Treino - Lote número 082, Erro: 1.4810, Acurácia: 0.6250
# Treino - Lote número 083, Erro: 0.3378, Acurácia: 0.7500
# Treino - Lote número 084, Erro: 0.2263, Acurácia: 0.8750
# Treino - Lote número 085, Erro: 0.0105, Acurácia: 1.0000
# Treino - Lote número 086, Erro: 0.3302, Acurácia: 0.8750
# Treino - Lote número 087, Erro: 0.3034, Acurácia: 0.8750
# Treino - Lote número 088, Erro: 0.2318, Acurácia: 0.8750
# Treino - Lote número 089, Erro: 0.0599, Acurácia: 1.0000
# Treino - Lote número 090, Erro: 0.0481, Acurácia: 1.0000
# Treino - Lote número 091, Erro: 0.3877, Acurácia: 0.7500
# Treino - Lote número 092, Erro: 1.3006, Acurácia: 0.8750
# Treino - Lote número 093, Erro: 0.6265, Acurácia: 0.8750
# Treino - Lote número 094, Erro: 0.2040, Acurácia: 0.8750
# Treino - Lote número 095, Erro: 0.0746, Acurácia: 1.0000
# Treino - Lote número 096, Erro: 0.0039, Acurácia: 1.0000
# Treino - Lote número 097, Erro: 0.0628, Acurácia: 1.0000
# Treino - Lote número 098, Erro: 0.1830, Acurácia: 0.8750
# Treino - Lote número 099, Erro: 0.8878, Acurácia: 0.8750
# Treino - Lote número 100, Erro: 0.2680, Acurácia: 0.8750
# Treino - Lote número 101, Erro: 0.1408, Acurácia: 0.8750
# Treino - Lote número 102, Erro: 0.7424, Acurácia: 0.8750
# Treino - Lote número 103, Erro: 1.0602, Acurácia: 0.7500
# Treino - Lote número 104, Erro: 0.0146, Acurácia: 1.0000
# Treino - Lote número 105, Erro: 0.4995, Acurácia: 0.7500
# Treino - Lote número 106, Erro: 0.0382, Acurácia: 1.0000
# Treino - Lote número 107, Erro: 0.5262, Acurácia: 0.7500
# Treino - Lote número 108, Erro: 0.0165, Acurácia: 1.0000
# Treino - Lote número 109, Erro: 0.5678, Acurácia: 0.8750
# Treino - Lote número 110, Erro: 0.8829, Acurácia: 0.7500
# Treino - Lote número 111, Erro: 0.2928, Acurácia: 0.8750
# Treino - Lote número 112, Erro: 0.4136, Acurácia: 0.8750
# Treino - Lote número 113, Erro: 0.1015, Acurácia: 1.0000
# Treino - Lote número 114, Erro: 0.0118, Acurácia: 1.0000
# Treino - Lote número 115, Erro: 0.0753, Acurácia: 1.0000
# Treino - Lote número 116, Erro: 0.1927, Acurácia: 0.8750
# Treino - Lote número 117, Erro: 0.4259, Acurácia: 0.7500
# Treino - Lote número 118, Erro: 0.1155, Acurácia: 1.0000
# Treino - Lote número 119, Erro: 0.1523, Acurácia: 1.0000
# Treino - Lote número 120, Erro: 0.1713, Acurácia: 0.8750
# Treino - Lote número 121, Erro: 0.3689, Acurácia: 0.7500
# Treino - Lote número 122, Erro: 1.6609, Acurácia: 0.7500
# Treino - Lote número 123, Erro: 0.0624, Acurácia: 1.0000
# Treino - Lote número 124, Erro: 0.3657, Acurácia: 0.8750
# Treino - Lote número 125, Erro: 0.5657, Acurácia: 0.7500
# Treino - Lote número 126, Erro: 0.0845, Acurácia: 1.0000
# Treino - Lote número 127, Erro: 0.1966, Acurácia: 0.8750
# Treino - Lote número 128, Erro: 0.0143, Acurácia: 1.0000
# Treino - Lote número 129, Erro: 0.5874, Acurácia: 0.8750
# Treino - Lote número 130, Erro: 0.3819, Acurácia: 0.8750
# Treino - Lote número 131, Erro: 0.1076, Acurácia: 0.8750
# Treino - Lote número 132, Erro: 0.8373, Acurácia: 0.8750
# Treino - Lote número 133, Erro: 0.0218, Acurácia: 1.0000
# Treino - Lote número 134, Erro: 0.1075, Acurácia: 0.8750
# Treino - Lote número 135, Erro: 0.0736, Acurácia: 1.0000
# Treino - Lote número 136, Erro: 0.4473, Acurácia: 0.8750
# Treino - Lote número 137, Erro: 0.7498, Acurácia: 0.7500
# Treino - Lote número 138, Erro: 0.0937, Acurácia: 0.8750
# Treino - Lote número 139, Erro: 0.0885, Acurácia: 1.0000
# Treino - Lote número 140, Erro: 0.5396, Acurácia: 0.8750
# Treino - Lote número 141, Erro: 0.0595, Acurácia: 1.0000
# Treino - Lote número 142, Erro: 0.1197, Acurácia: 0.8750
# Treino - Lote número 143, Erro: 0.6340, Acurácia: 0.8750
# Treino - Lote número 144, Erro: 0.0276, Acurácia: 1.0000
# Treino - Lote número 145, Erro: 0.7428, Acurácia: 0.8750
# Treino - Lote número 146, Erro: 0.0123, Acurácia: 1.0000
# Treino - Lote número 147, Erro: 0.0658, Acurácia: 1.0000
# Treino - Lote número 148, Erro: 0.2856, Acurácia: 0.7500
# Treino - Lote número 149, Erro: 0.0509, Acurácia: 1.0000
# Treino - Lote número 150, Erro: 0.2802, Acurácia: 0.8750
# Treino - Lote número 151, Erro: 0.1750, Acurácia: 1.0000
# Treino - Lote número 152, Erro: 0.0417, Acurácia: 1.0000
# Treino - Lote número 153, Erro: 0.0191, Acurácia: 1.0000
# Treino - Lote número 154, Erro: 0.0328, Acurácia: 1.0000
# Treino - Lote número 155, Erro: 0.1071, Acurácia: 1.0000
# Treino - Lote número 156, Erro: 0.3778, Acurácia: 0.8750
# Treino - Lote número 157, Erro: 0.1732, Acurácia: 0.8750
# Treino - Lote número 158, Erro: 0.3677, Acurácia: 0.8750
# Treino - Lote número 159, Erro: 0.0873, Acurácia: 1.0000
# Treino - Lote número 160, Erro: 0.0209, Acurácia: 1.0000
# Treino - Lote número 161, Erro: 0.0228, Acurácia: 1.0000
# Treino - Lote número 162, Erro: 0.0515, Acurácia: 1.0000
# Treino - Lote número 163, Erro: 0.0535, Acurácia: 1.0000
# Treino - Lote número 164, Erro: 0.0026, Acurácia: 1.0000
# Treino - Lote número 165, Erro: 0.2488, Acurácia: 0.8750
# Treino - Lote número 166, Erro: 0.0352, Acurácia: 1.0000
# Treino - Lote número 167, Erro: 0.2290, Acurácia: 0.8750
# Treino - Lote número 168, Erro: 0.0165, Acurácia: 1.0000
# Treino - Lote número 169, Erro: 0.0481, Acurácia: 1.0000
# Treino - Lote número 170, Erro: 0.0173, Acurácia: 1.0000
# Treino - Lote número 171, Erro: 0.2416, Acurácia: 0.8750
# Treino - Lote número 172, Erro: 0.2228, Acurácia: 0.8750
# Treino - Lote número 173, Erro: 0.1105, Acurácia: 0.8750
# Treino - Lote número 174, Erro: 0.0490, Acurácia: 1.0000
# Treino - Lote número 175, Erro: 0.2719, Acurácia: 0.8750
# Treino - Lote número 176, Erro: 0.1621, Acurácia: 0.8750
# Treino - Lote número 177, Erro: 0.3765, Acurácia: 0.8750
# Treino - Lote número 178, Erro: 0.1313, Acurácia: 1.0000
# Treino - Lote número 179, Erro: 0.0032, Acurácia: 1.0000
# Treino - Lote número 180, Erro: 0.0459, Acurácia: 1.0000
# Treino - Lote número 181, Erro: 0.0020, Acurácia: 1.0000
# Treino - Lote número 182, Erro: 0.1873, Acurácia: 0.8750
# Treino - Lote número 183, Erro: 0.4950, Acurácia: 0.8750
# Treino - Lote número 184, Erro: 0.0168, Acurácia: 1.0000
# Treino - Lote número 185, Erro: 0.9849, Acurácia: 0.7500
# Treino - Lote número 186, Erro: 0.4272, Acurácia: 0.7500
# Treino - Lote número 187, Erro: 0.3257, Acurácia: 0.8750
# Treino - Lote número 188, Erro: 0.0057, Acurácia: 1.0000
# Treino - Lote número 189, Erro: 0.0154, Acurácia: 1.0000
# Treino - Lote número 190, Erro: 0.0033, Acurácia: 1.0000
# Treino - Lote número 191, Erro: 0.0462, Acurácia: 1.0000
# Treino - Lote número 192, Erro: 0.1979, Acurácia: 1.0000
# Treino - Lote número 193, Erro: 0.0562, Acurácia: 1.0000
# Treino - Lote número 194, Erro: 0.1180, Acurácia: 0.8750
# Treino - Lote número 195, Erro: 0.4439, Acurácia: 0.8750
# Treino - Lote número 196, Erro: 0.0876, Acurácia: 1.0000
# Treino - Lote número 197, Erro: 0.9139, Acurácia: 0.8750
# Treino - Lote número 198, Erro: 0.1077, Acurácia: 1.0000
# Treino - Lote número 199, Erro: 0.2638, Acurácia: 0.7500
# Treino - Lote número 200, Erro: 0.0469, Acurácia: 1.0000
# Treino - Lote número 201, Erro: 0.3642, Acurácia: 0.8750
# Validação - Lote número: 000, Erro: 0.5262, Acurácia: 0.7500
# Validação - Lote número: 001, Erro: 2.4957, Acurácia: 0.7500
# Validação - Lote número: 002, Erro: 1.7773, Acurácia: 0.7500
# Validação - Lote número: 003, Erro: 0.2562, Acurácia: 1.0000
# Época : 020, Treino: Erro: 0.2734, Acurácia: 91.7079%,
# 		Validação : Erro : 1.4505, Acurácia: 77.7778%, Tempo: 11.3179s

# %%
# Mostra o erro de treino e validação a cada época treinada

historico = np.array(historico)

plt.plot(historico[:,0:2])
plt.legend(['Erro Treino', 'Erro Validação'])
plt.xlabel('Época')
plt.ylabel('Erro')
plt.ylim(0,1)
plt.show()

# %%
def predicao_tim_maia(modelo, arquivo_imagem_teste):
    '''
    Função para realizar a predição do status do AR
    Parâmetros
        :param modelo: modelo para testar
        :param arquivo_imagem_teste: caminho para imagem de teste
    '''
    
    transformacao = transformacoes_de_imagens['teste']

    imagem_teste = PIL.Image.open(arquivo_imagem_teste)
    plt.imshow(imagem_teste)
    
    tensor_imagem_teste = transformacao(imagem_teste)

    # Testa se voce é rico, ops, se tem uma placa NVIDIA :)
    if torch.cuda.is_available():
        tensor_imagem_teste = tensor_imagem_teste.view(1, 3, image_size, image_size).cuda()
    else:
        tensor_imagem_teste = tensor_imagem_teste.view(1, 3, image_size, image_size)
    
    dict_predicoes = dict()
    
    # Não precisa atualizar os coeficientes do modelo
    with torch.no_grad():
        modelo.eval()
        # Modelo retorna as probabilidades em log (log softmax)
        saida = modelo(tensor_imagem_teste)
        
        # torch.exp para voltar a probabilidade de log para a probabilidade linear
        ps = torch.exp(saida)
        
        # topk retorna o os k maiores valores do tensor
        # o tensor de probabilidades vai trazer na 1a posição a classe com maior
        # probabilidade de predição
        topk, topclass = ps.topk(numero_de_classes, dim=1)
        for i in range(numero_de_classes):
            dict_predicoes[indice_para_classe[topclass.cpu().numpy()[0][i]]] = topk.cpu().numpy()[0][i]
    
    return dict_predicoes

# %%
classe = 'nao_e_assinatura'
pasta = f'./data/teste/{classe}/'
imagem = os.path.join(pasta, os.listdir(pasta)[1])

predicao_tim_maia(modelo_treinado, imagem)
# Out:
# {'assinado': 0.9965844,
#  'nao_assinado': 0.00292883,
#  'nao_e_assinatura': 0.00048675857}

# %%
torch.save(modelo_treinado, './modelos/melhor_modelo.pt')
